# %% [markdown]
# # BoltzRank #
# ## Luca Negrini - Mat. 956516 ##
# ### From "BoltzRank: Learning to Maximize Expected Ranking Gain" ###
# #### Maxims M. Volkovs, Richard S. Zemel ####

# %% [markdown]
# ------
# #### Initialization ####

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib notebook

# %load_ext cython

# install lightgbm (required only on first run)
# import sys
# !{sys.executable} -m pip install lightgbm

import os
import os.path
import numpy as np
import lightgbm
import matplotlib.pyplot as plt

# see http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_svmlight_file.html
from sklearn.datasets import load_svmlight_file 

# datasets available at: 
# https://www.microsoft.com/en-us/research/project/mslr/
DATASET_FOLDER = "C:/opt/kiis-training/MSLR-WEB10K/Fold1/"
PERM_FOLDER = DATASET_FOLDER + "perms/"
METRIC_NAME = 'ndcg@10'#'Custom-MSE'

# %% [markdown]
# -----
# #### Data loading ####

# %%
def ensureFile(path):
    if not os.path.exists(path) or not os.path.isfile(path):
        raise FileNotFoundError("'" + path + "': no such file")        
    return path

def retrieveFileNames():
    folder = DATASET_FOLDER + '/' if DATASET_FOLDER[-1:] != '/' else DATASET_FOLDER
    train_file = ensureFile(folder + "train.txt")
    valid_file = ensureFile(folder + "vali.txt")
    test_file = ensureFile(folder + "test.txt")
    return train_file, valid_file, test_file

def loadDataset(path):
    return load_svmlight_file(path, query_id=True)

def loadLightGBM(svmlight_dataset):
    query_lens = [sum(1 for _ in group) for key, group in itertools.groupby(svmlight_dataset[2])]
    return lightgbm.Dataset(data=svmlight_dataset[0], label=svmlight_dataset[1], group=query_lens)

# %%
class Query:
    def __init__(self, qid):
        self.qid = qid
        self.labels_to_docs = {}
    def addlabel(self, label):
        if not label in self.labels_to_docs:
            self.labels_to_docs[label] = list()
    def adddoc(self, label, doc):
        self.labels_to_docs[label].append(doc)
    def finalize(self, alllabels):
        self.labels = np.zeros(len(self.labels_to_docs.keys()), dtype=int)
        self.docs = np.empty(len(self.labels_to_docs.keys()), dtype=object)
        i = 0
        totaldocs = 0
        sorteddict = sorted(self.labels_to_docs.items(), reverse = True)
        for label, docs in sorteddict:
            self.labels[i] = label
            self.docs[i] = np.zeros(len(docs), dtype=int)
            for j in range(len(docs)):
                self.docs[i][j] = docs[j]
            i += 1
            totaldocs += len(docs)
        self.alldocs = np.concatenate(self.docs)
        self.flatlabels = np.zeros(totaldocs, dtype=np.double)
        i = 0
        for label, docs in sorteddict:
            for j in range(len(docs)):
                self.flatlabels[i] = label
                i += 1       
        k = min(10, len(self.alldocs))
        self.idealdcg = dcg_k(self.alldocs, alllabels, k) 
        del self.labels_to_docs
    def setperms(self, perms):
        self.perms = perms
    def setprobs(self, probs):
        self.probs = probs
    def setndcgs(self, ndcgs):
        self.ndcgs = ndcgs
    def __repr__(self):  
        return str(self)
    def __str__(self):
        res = "Query " + str(self.qid) + "["
        res += "\nideal dcg: " + str(self.idealdcg)
        for i in range(len(self.labels)):
            res += "\n" + str(self.labels[i]) + " -> " + str(self.docs[i])
        res += "]"
        if hasattr(self, 'perms'):
            for i in range(len(self.perms)):
                res += "\n[" + str(self.perms[i]) + "] -> p: " + str(self.probs[i]) + ", dcg: " + str(self.ndcgs[i])
        else:
            res += "\nNo permutations computed yet"
        return res

# %%
# parameters:
#  dataset: svmlight_dataset 
#      the datset to process
# returned values:
#  query_to_labels_to_documents: dict(int -> dict(float -> list(int)))
#      a map containing, for each query in the dataset, the documents (row index in the dataset) provided 
#      in the input dataset grouped by label
#  doc_to_query: dict(document -> query)
#      a mapping between document (row index in the dataset) and the relative query
def mapQueryToDocuments(dataset):
    queries = {}
    doc_to_query = {} 
    alllabels = np.negative(np.ones(len(dataset[2]), dtype=np.double))
    for i in range(0, len(dataset[2])):
        if not dataset[2][i] in queries:
            queries[dataset[2][i]] = Query(dataset[2][i])
        query = queries[dataset[2][i]]
        query.addlabel(dataset[1][i])
        query.adddoc(dataset[1][i], i)
        doc_to_query[i] = query.qid
        alllabels[i] = dataset[1][i]
        
    for q in queries.values():
        q.finalize(alllabels)
    
    return queries, alllabels, doc_to_query

# %% [markdown]
# -----
# #### BoltzRank logic in Cython ####

# %%
# %%cython
#
# from cython.parallel import prange
# from cython import boundscheck, wraparound
#
# # The sign-preserving function introduced in formula (4) and defined in formula (5). The implementation follows
# # the one proposed near the end of Section 4.2.
# #
# # parameters:
# #  x: double
# #      the difference in rankings between the two current documents
# #  m: int
# #      the number of documents available for the current query
# # returned values:
# #  val: double
# #      the result of the function
# @boundscheck(False)
# @wraparound(False)
# cdef double g_q(double x, int m) nogil:
#     return (2 * x) / (m - 1)
#
# # The energy function E(R|S) defined in formula (4). This represents the incompatibility between the
# # given ranking and the given score. More energy means less compatibility
# #
# # parameters:
# #  rank: int[:]
# #      the array of document IDs (row index in the dataset) representing the ranking
# #  scores: double[:]
# #      the array of document scores, score of document i will be retrieved from scores[i]
# # returned values:
# #  val: double
# #      the energy of the ranking w.r.t. the target scores. The lower, the better.
# @boundscheck(False)
# @wraparound(False)
# cdef double energy(int[:] rank, double[:] scores) nogil:
#     cdef int m = len(rank)
#     if m == 1 or m == 0:
#         return 0
#     cdef double factor = 2 / (m * (m - 1))
#     cdef double res = 0
#     cdef int j
#     cdef int k
#     for k in prange(m, schedule='static', num_threads=8):
#         for j in range(k + 1, m):
#             res += g_q(j - k, m) * (scores[rank[j]] - scores[rank[k]])
#     return factor * res
#
# from libc.math cimport exp
#
# # The approximate rank probability P[Rq](R|S) defined in formula (12). This approximates the probability of a ranking
# # given a scoring. Since the effective computation is intractable due to the exponentail number of possible rankings,
# # this is computed through a montecarlo estimate over sample ranking sets
# #
# # parameters:
# #  sampleSet: int[:,:]
# #      the array containing all sample rankings, expresed as arrays of document IDs (row index in the dataset)
# #  rank: int[:]
# #      the ranking whose probability is to be computed, expressed as array of document IDs (row index in the dataset)
# #  scores: double[:]
# #      the scores to be used for the energy computation, score of document i will be retrieved from scores[i]
# # returned values:
# #  val: double
# #      the probability of the given ranking
# @boundscheck(False)
# @wraparound(False)
# cpdef double[:] approx_rank_probabilities(int[:,:] sampleSet, double[:] norm_probs, double[:] scores) nogil:
#     cdef double norm = 0
#     cdef int r
#     for r in prange(len(sampleSet), schedule='static', num_threads=8):
#         norm_probs[r] = exp(-energy(sampleSet[r], scores))
#         norm += norm_probs[r]
#     for r in prange(len(norm_probs), schedule='static', num_threads=8):
#         norm_probs[r] = norm_probs[r] / norm
#     return norm_probs
#
# from math import factorial
# import numpy as np
#
# #int[:,:] source, int i, int j, int count, int[:,:] perms
# #return: number of not computed permutations
# @boundscheck(False)
# @wraparound(False)
# def perform_permutation(query, int i, int j, int count, int[:,:] perms, int start):
#     if not i in query.labels or not j in query.labels:
#         # no swapping possible
#         return count, start
#     # find the indexes of the desired labels
#     i = [k for k in range(len(query.labels)) if query.labels[k] == i][0]
#     j = [k for k in range(len(query.labels)) if query.labels[k] == j][0]
#     # find maximum amount of permutations that can be done
#     cdef int _min = min(len(query.docs[i]), len(query.docs[j]))
#     cdef int amount = min(count, _min)
#     # randomly selects the indexes
#     cdef int[:] first = np.random.choice(len(query.docs[i]), amount)
#     cdef int[:] second = np.random.choice(len(query.docs[j]), amount)
#     # perform the single-element permutations
#     cdef int k
#     cdef perm
#     cdef int[:] p
#     for k in range(amount):
#         perm = query.docs.copy()
#         perm[i][first[k]], perm[j][second[k]] = query.docs[j][second[k]], query.docs[i][first[k]]
#         p = np.concatenate(perm)
#         perms[start + k] = p
#     return count - amount, start + amount
#
# import random
#
# @boundscheck(False)
# @wraparound(False)
# cdef bint contained(int[:,:] container, int[:] array) nogil:
#     cdef bint match
#     cdef int i
#     cdef int j
#     for i in prange(len(container), schedule='static', num_threads=8):
#         if container[i][0] == -1 or len(container[i]) != len(array):
#             continue
#         else:
#             match = True
#             for j in range(len(container[i])):
#                 if container[i][j] != array[j]:
#                     match = False
#                     break
#             if match:
#                 return True
#     return False
#
# cdef void setrow(int[:,:] container, int pos, int[:] array) nogil:
#     cdef int i
#     for i in prange(len(container[pos]), schedule='static', num_threads=8):
#         container[pos][i] = array[i]
#
#
# #source: label -> docid*, i: int, j: int, count: int, perms_with_prob: tuple<int> -> float
# #return: number of not computed permutations
# @boundscheck(False)
# @wraparound(False)
# def perform_permutation2(query, int i, int j, int count, int[:,:] perms, int start):
#     if not i in query.labels or not j in query.labels:
#         # no swapping possible
#         return count, start
#     # find the indexes of the desired labels
#     i = [k for k in range(len(query.labels)) if query.labels[k] == i][0]
#     j = [k for k in range(len(query.labels)) if query.labels[k] == j][0]
#     cdef int c = 0
#     cdef int _min = min(len(query.docs[i]), len(query.docs[j]))
#     cdef int amount = max(1, int(_min * .5))
#     limit = factorial(_min) / (factorial(amount) * factorial(_min - amount))
#     cdef int k
#     cdef int d
#     for k in range(count):
#         perm = query.docs.copy()
#         first = random.sample(range(len(query.docs[i])), k=amount)
#         second = random.sample(range(len(query.docs[j])), k=amount)
#         for d in range(len(first)):
#             perm[i][first[d]], perm[j][second[d]] = query.docs[j][second[d]], query.docs[i][first[d]]
#         p = np.concatenate(perm)
#         if not contained(perms, p):
#             setrow(perms, start + c, p)
#             c += 1
#             if c == limit:
#                 return count - c, start + c
#         else:
#             k -= 1
#     return 0, start + c
#
# import itertools
#
# @boundscheck(False)
# @wraparound(False)
# cdef int[:,:] allPerms(int[:] source, long long fact):
#     cdef int i = 0
#     cdef int k
#     perm = itertools.permutations(source)
#     cdef int[:,:] result = np.zeros((fact, len(source)), dtype=int)
#     for p in perm:
#         for k in range(len(p)):
#             result[i][k] = p[k]
#         i += 1
#     return result
#
# RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS = 100
# RANK_SAMPLE_SET_DISTRIBUTIONS = [
#                                 int(.30 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->0
#                                 int(.22 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->1
#                                 int(.18 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->2
#                                 int(.12 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->3
#                                 int(.10 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 3->0
#                                 int(.06 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 3->1
#                                 int(.02 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 3->2
#                                 int(.0 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 2->0
#                                 int(.0 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 2->1
#                                 int(.0 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS)  # 1->0
#                                 ]
#
# #cdef int[:,:] process_query(int query, double[:] labels, int[:,:] docs, double[:] probs) nogil:
# @boundscheck(False)
# @wraparound(False)
# def process_query(query, alllabels):
#     cdef int carry = 0
#     fact = factorial(len(query.alldocs))
#     cdef perms
#     cdef int last = 0
#     if fact <= RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS:
#         # evaluate all possible permutations, each one representing a different ranking
#         perms = allPerms(query.alldocs, fact)
#     else:
#         perms = np.negative(np.ones((RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS, len(query.alldocs)), dtype=int))
#         # switch the labels of the documents, then sort the documents by label to obtain a ranking
#         carry, last = perform_permutation2(query, 4, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[0], perms, last)
#         carry, last = perform_permutation2(query, 4, 1, RANK_SAMPLE_SET_DISTRIBUTIONS[1] + carry, perms, last)
#         carry, last = perform_permutation2(query, 4, 2, RANK_SAMPLE_SET_DISTRIBUTIONS[2] + carry, perms, last)
#         carry, last = perform_permutation2(query, 4, 3, RANK_SAMPLE_SET_DISTRIBUTIONS[3] + carry, perms, last)
#         carry, last = perform_permutation2(query, 3, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[4] + carry, perms, last)
#         carry, last = perform_permutation2(query, 3, 1, RANK_SAMPLE_SET_DISTRIBUTIONS[5] + carry, perms, last)
#         carry, last = perform_permutation2(query, 3, 2, RANK_SAMPLE_SET_DISTRIBUTIONS[6] + carry, perms, last)
#         carry, last = perform_permutation2(query, 2, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[7] + carry, perms, last)
#         carry, last = perform_permutation2(query, 2, 1, RANK_SAMPLE_SET_DISTRIBUTIONS[8] + carry, perms, last)
#         carry, last = perform_permutation2(query, 1, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[9] + carry, perms, last)
#         if carry != 0:
#             if not query.alldocs in perms:
#                 perms[last] = query.alldocs
#         perms = perms[perms.max(axis=1)>=0]
#     cdef double[:] probs = np.zeros(len(perms))
#     cdef double[:] ndcgs = np.zeros(len(perms))
#     query.setperms(perms)
#     query.setprobs(approx_rank_probabilities(perms, probs, alllabels))
#     cdef int k = min(10, len(perms[0]))
#     for i in range(len(perms)):
#         ndcgs[i] = ndcg_k(perms[i], alllabels, k, query.idealdcg)
#     query.setndcgs(ndcgs)
#     return query
#
# from libc.math cimport log, log2
#
# @boundscheck(False)
# @wraparound(False)
# cdef double cross_entropy(double[:] probs, double[:] scores_probs) nogil:
#     cdef double result = 0
#     cdef int i
#     for i in prange(len(probs), schedule='static', num_threads=8):
#         result += probs[i] * log(scores_probs[i])
#     return -result
#
# @boundscheck(False)
# @wraparound(False)
# cpdef double dcg_k(int[:] rank, double[:] scores, int k) nogil:
#     cdef double result = 0
#     cdef int i
#     for i in prange(k, schedule='static', num_threads=8):
#         result += (2**scores[rank[i]] - 1) / (log2(i + 2)) # should be i+1, but with numbering starting from 1 instead of 0
#     return result
#
#
# @boundscheck(False)
# @wraparound(False)
# cdef double ndcg_k(int[:] rank, double[:] scores, int k, double ideal) nogil:
#     if ideal == 0:
#         return 1.0
#     return dcg_k(rank, scores, k) / ideal
#
# @boundscheck(False)
# @wraparound(False)
# cdef double monte_carlo_gain(int[:,:] perms, double[:] scores_probs, double[:] scores, double[:] ndcgs) nogil:
#     cdef double result = 0
#     cdef int i
#     cdef int k = min(10, len(perms[0]))
#     for i in prange(len(perms), schedule='static', num_threads=8):
#         result += scores_probs[i] * ndcgs[i]
#     return result
#
# @boundscheck(False)
# @wraparound(False)
# def eval_grads(queries, doc_to_query, preds, labels):
#     cdef double lam = .9
#     query_to_gain = {}
#     cdef double[:] score_probs
#     for q in queries.values():
#         score_probs = np.zeros(len(q.probs), dtype=np.double)
#         score_probs = approx_rank_probabilities(q.perms, score_probs, preds)
#         query_to_gain[q.qid] = lam * monte_carlo_gain(q.perms, score_probs, preds, q.ndcgs)
#         query_to_gain[q.qid] -= (1 - lam) * cross_entropy(q.probs, score_probs)
#
#     cdef double[:] gain = np.ones_like(preds)
#     cdef int i
#     for i in range(len(gain)):
#         gain[i] = query_to_gain[doc_to_query[i]]
#
#     cdef double[:] hess = np.ones_like(gain)
#     return gain, hess
# Out:
# warning: C:\Users\NegriniL\.ipython\cython\_cython_magic_b74475f19ffd592abb08b23af31924e9.pyx:130:33: Use boundscheck(False) for faster access
# warning: C:\Users\NegriniL\.ipython\cython\_cython_magic_b74475f19ffd592abb08b23af31924e9.pyx:130:22: Use boundscheck(False) for faster access

# %%
train_file, valid_file, test_file = retrieveFileNames()

print("training file: " + train_file)
print("validation file: " + valid_file)
print("test file: " + test_file)
    
print("loading datasets... ")
import time
start = time.process_time()
train_dataset = loadDataset(train_file)
print("train dataset loading took " + str(time.process_time() - start) + " s")
start = time.process_time()
valid_dataset = loadDataset(valid_file)
print("validation dataset loading took " + str(time.process_time() - start) + " s")
start = time.process_time()
test_dataset = loadDataset(test_file)
print("test dataset loading took " + str(time.process_time() - start) + " s")

import itertools
print("converting datasets to LightGBM format... ")
train_lgb = loadLightGBM(train_dataset)
valid_lgb = loadLightGBM(valid_dataset)
test_lgb = loadLightGBM(test_dataset)

print("done")
# Out:
# training file: C:/opt/kiis-training/MSLR-WEB10K/Fold1/train.txt
# validation file: C:/opt/kiis-training/MSLR-WEB10K/Fold1/vali.txt
# test file: C:/opt/kiis-training/MSLR-WEB10K/Fold1/test.txt
# loading datasets...
# train dataset loading took 43.671875 s
# validation dataset loading took 14.421875 s
# test dataset loading took 14.90625 s
# converting datasets to LightGBM format...
# done

# %%
print("creating query-documents mappings...")
queries, alllabels, doc_to_query = mapQueryToDocuments(train_dataset)
print("done")

print("creating sample sets...")
start = time.process_time()
for q in queries.values():
    queries[q.qid] = process_query(q, alllabels)
print("sample set creation took " + str(time.process_time() - start) + " s")
print("done")
# Out:
# creating query-documents mappings...
# done
# creating sample sets...
# sample set creation took 69.859375 s
# done

# %%
freq = {}
totperms = 0
for query in queries.values():
    for ndcg in query.ndcgs:
        totperms += 1
        if not ndcg in freq.keys():
            freq[ndcg] = 0
        freq[ndcg] += 1

x = []
y = []
for ndcg, f in sorted(freq.items()):
    x.append(ndcg)
    y.append(f)
    
plt.figure(figsize=(9,6), tight_layout=True)
plt.plot(x, y, '.')
plt.grid()
plt.xlabel("ndcg@10")
plt.ylabel("frequency")
plt.yscale("log")
plt.title("ndcg@10 frequencies over " + str(totperms) + " permutations")
# Out:
# Text(0.5, 1.0, 'ndcg@10 frequencies over 523881 permutations')

# %%
freq = {}
for query in queries.values():
    for prob in query.probs:
        if not prob in freq.keys():
            freq[prob] = 0
        freq[prob] += 1

x = []
y = []
for prob, f in sorted(freq.items()):
    x.append(prob)
    y.append(f)
    
plt.figure(figsize=(9,6), tight_layout=True)
plt.plot(x, y, '.')
plt.grid()
plt.xlabel("# rank")
plt.ylabel("probability")
plt.yscale("log")
plt.title("probabilities of the " + str(totperms) + " permutations")
# Out:
# Text(0.5, 1.0, 'probabilities of the 523881 permutations')

# %%
def check(q, k):
    indexes = set(range(0, len(q.perms)))
    indexes.remove(k)
    result = []
    for i in range(len(q.perms[k])):
        tmp = set(indexes)
        for j in tmp:
            if q.perms[k][i] != q.perms[j][i]:
                indexes.remove(j)
    for w in indexes:
        if w < k:
            result.append((w, k))
        else: 
            result.append((k,w))
    return result

def checkRepetitions():
    global queries
    same = dict()
    for q in queries.values():
        for i in range(len(q.perms)):
            r = check(q, i)
            if len(r) != 0:
                if not q.qid in same.keys():
                    same[q.qid] = set()
                for t in r:
                    same[q.qid].add(t)

    print(str(len(same.keys())) + "/" + str(len(queries.keys())) + " queries have duplicate permutations")
    for q, s in same.items():
        print("query " + str(q) + " has repeated permutations: " + str(s))
        
checkRepetitions()
# Out:
# 244/6000 queries have duplicate permutations
# query 601 has repeated permutations: {(3, 5)}
# query 826 has repeated permutations: {(5, 7)}
# query 886 has repeated permutations: {(6, 8)}
# query 1021 has repeated permutations: {(1, 3)}
# query 1156 has repeated permutations: {(14, 16)}
# query 1351 has repeated permutations: {(2, 4)}
# query 1711 has repeated permutations: {(1, 3)}
# query 1846 has repeated permutations: {(1, 3)}
# query 2956 has repeated permutations: {(11, 13)}
# query 4006 has repeated permutations: {(13, 15)}
# query 4291 has repeated permutations: {(29, 31)}
# query 4426 has repeated permutations: {(3, 5)}
# query 4726 has repeated permutations: {(4, 6)}
# query 5161 has repeated permutations: {(21, 23)}
# query 5686 has repeated permutations: {(2, 4)}
# query 5701 has repeated permutations: {(3, 5)}
# query 6391 has repeated permutations: {(18, 20), (12, 14)}
# query 6586 has repeated permutations: {(0, 2)}
# query 6916 has repeated permutations: {(5, 7)}
# query 7531 has repeated permutations: {(97, 99)}
# query 7741 has repeated permutations: {(6, 8)}
# query 8356 has repeated permutations: {(61, 63)}
# query 9451 has repeated permutations: {(5, 7)}
# query 9466 has repeated permutations: {(1, 3)}
# query 9736 has repeated permutations: {(5, 7)}
# query 9886 has repeated permutations: {(1, 3)}
# query 9931 has repeated permutations: {(2, 4)}
# query 10231 has repeated permutations: {(3, 5)}
# query 10666 has repeated permutations: {(73, 75)}
# query 10696 has repeated permutations: {(5, 7)}
# query 10801 has repeated permutations: {(1, 3)}
# query 11176 has repeated permutations: {(10, 12)}
# query 11881 has repeated permutations: {(73, 75)}
# query 12376 has repeated permutations: {(3, 5)}
# query 12541 has repeated permutations: {(5, 7)}
# query 12646 has repeated permutations: {(3, 5)}
# query 13261 has repeated permutations: {(8, 10)}
# query 13306 has repeated permutations: {(8, 10)}
# query 14581 has repeated permutations: {(8, 10)}
# query 15091 has repeated permutations: {(18, 20)}
# query 15181 has repeated permutations: {(1, 3)}
# query 15391 has repeated permutations: {(5, 7)}
# query 15451 has repeated permutations: {(2, 4)}
# query 16651 has repeated permutations: {(2, 4)}
# query 17221 has repeated permutations: {(3, 5)}
# query 17686 has repeated permutations: {(8, 10)}
# query 17746 has repeated permutations: {(69, 71)}
# query 17911 has repeated permutations: {(8, 10)}
# query 18076 has repeated permutations: {(3, 5)}
# query 18106 has repeated permutations: {(4, 6)}
# query 18766 has repeated permutations: {(2, 4)}
# query 19516 has repeated permutations: {(5, 7), (6, 8)}
# query 20146 has repeated permutations: {(9, 11)}
# query 20386 has repeated permutations: {(1, 3)}
# query 21451 has repeated permutations: {(13, 15)}
# query 22126 has repeated permutations: {(3, 5)}
# query 22366 has repeated permutations: {(11, 13)}
# query 22381 has repeated permutations: {(2, 4)}
# query 23026 has repeated permutations: {(5, 7)}
# query 23266 has repeated permutations: {(2, 4)}
# query 23731 has repeated permutations: {(4, 6)}
# query 24136 has repeated permutations: {(6, 8)}
# query 24391 has repeated permutations: {(12, 14)}
# query 24556 has repeated permutations: {(12, 14)}
# query 24991 has repeated permutations: {(8, 10)}
# query 25081 has repeated permutations: {(6, 8)}
# query 25561 has repeated permutations: {(5, 7)}
# query 26026 has repeated permutations: {(1, 3)}
# query 26056 has repeated permutations: {(3, 5)}
# query 26716 has repeated permutations: {(6, 8)}
# query 26806 has repeated permutations: {(3, 5)}
# query 27076 has repeated permutations: {(1, 3)}
# query 27211 has repeated permutations: {(6, 8)}
# query 27541 has repeated permutations: {(11, 13)}
# query 28081 has repeated permutations: {(29, 31)}
# query 28126 has repeated permutations: {(3, 5)}
# query 28276 has repeated permutations: {(5, 7)}
# query 29041 has repeated permutations: {(5, 7)}
# query 29326 has repeated permutations: {(1, 3)}
# query 29971 has repeated permutations: {(3, 5)}
# query 304 has repeated permutations: {(4, 6)}
# query 844 has repeated permutations: {(63, 65)}
# query 874 has repeated permutations: {(6, 8)}
# query 1009 has repeated permutations: {(17, 19)}
# query 1024 has repeated permutations: {(5, 7)}
# query 1189 has repeated permutations: {(44, 46)}
# query 1459 has repeated permutations: {(1, 3)}
# query 2239 has repeated permutations: {(7, 9)}
# query 2434 has repeated permutations: {(14, 16)}
# query 2629 has repeated permutations: {(8, 10)}
# query 3454 has repeated permutations: {(5, 7)}
# query 3619 has repeated permutations: {(3, 5)}
# query 4054 has repeated permutations: {(9, 11), (6, 8)}
# query 4279 has repeated permutations: {(3, 5)}
# query 4414 has repeated permutations: {(2, 4)}
# query 4609 has repeated permutations: {(10, 12)}
# query 4744 has repeated permutations: {(3, 5)}
# query 4759 has repeated permutations: {(10, 12)}
# query 4804 has repeated permutations: {(59, 61)}
# query 5089 has repeated permutations: {(3, 5)}
# query 6769 has repeated permutations: {(1, 3)}
# query 7219 has repeated permutations: {(9, 11)}
# query 8209 has repeated permutations: {(5, 7)}
# query 8374 has repeated permutations: {(69, 71)}
# query 8419 has repeated permutations: {(6, 8)}
# query 8539 has repeated permutations: {(3, 5)}
# query 8659 has repeated permutations: {(6, 8)}
# query 8989 has repeated permutations: {(5, 7)}
# query 10174 has repeated permutations: {(9, 11)}
# query 10369 has repeated permutations: {(3, 5)}
# query 10384 has repeated permutations: {(3, 5)}
# query 11059 has repeated permutations: {(11, 13)}
# query 11809 has repeated permutations: {(9, 11), (8, 10)}
# query 11974 has repeated permutations: {(3, 5)}
# query 12259 has repeated permutations: {(5, 7)}
# query 13189 has repeated permutations: {(18, 20)}
# query 13204 has repeated permutations: {(2, 4)}
# query 14119 has repeated permutations: {(2, 4)}
# query 15514 has repeated permutations: {(9, 11)}
# query 15619 has repeated permutations: {(0, 2)}
# query 16444 has repeated permutations: {(23, 25)}
# query 17059 has repeated permutations: {(5, 7)}
# query 17119 has repeated permutations: {(43, 45)}
# query 17149 has repeated permutations: {(3, 5)}
# query 17329 has repeated permutations: {(5, 7)}
# query 17404 has repeated permutations: {(17, 19)}
# query 17794 has repeated permutations: {(1, 3)}
# query 17974 has repeated permutations: {(5, 7)}
# query 18139 has repeated permutations: {(14, 16)}
# query 18244 has repeated permutations: {(9, 11)}
# query 18379 has repeated permutations: {(5, 7)}
# query 18439 has repeated permutations: {(5, 7), (6, 8)}
# query 18889 has repeated permutations: {(5, 7)}
# query 19279 has repeated permutations: {(5, 7)}
# query 20029 has repeated permutations: {(8, 10)}
# query 20074 has repeated permutations: {(14, 16)}
# query 20164 has repeated permutations: {(3, 5)}
# query 20209 has repeated permutations: {(5, 7)}
# query 20779 has repeated permutations: {(3, 5)}
# query 20869 has repeated permutations: {(11, 13)}
# query 20929 has repeated permutations: {(1, 3)}
# query 21244 has repeated permutations: {(1, 3)}
# query 21319 has repeated permutations: {(4, 6)}
# query 21379 has repeated permutations: {(3, 5)}
# query 21499 has repeated permutations: {(1, 3)}
# query 22249 has repeated permutations: {(8, 10)}
# query 22324 has repeated permutations: {(8, 10)}
# query 22534 has repeated permutations: {(6, 8)}
# query 23374 has repeated permutations: {(36, 38)}
# query 23524 has repeated permutations: {(3, 5)}
# query 23764 has repeated permutations: {(3, 5)}
# query 24169 has repeated permutations: {(4, 6)}
# query 24454 has repeated permutations: {(9, 11), (8, 10)}
# query 24919 has repeated permutations: {(69, 71)}
# query 25744 has repeated permutations: {(5, 7)}
# query 25954 has repeated permutations: {(3, 5)}
# query 26284 has repeated permutations: {(0, 2)}
# query 26314 has repeated permutations: {(1, 3)}
# query 26764 has repeated permutations: {(6, 8)}
# query 27109 has repeated permutations: {(1, 3)}
# query 27349 has repeated permutations: {(1, 3)}
# query 27694 has repeated permutations: {(11, 13)}
# query 27709 has repeated permutations: {(5, 7)}
# query 27784 has repeated permutations: {(11, 13)}
# query 27799 has repeated permutations: {(22, 24), (20, 22), (20, 24)}
# query 28549 has repeated permutations: {(2, 4)}
# query 28984 has repeated permutations: {(5, 7)}
# query 29584 has repeated permutations: {(5, 7)}
# query 262 has repeated permutations: {(2, 4)}
# query 2017 has repeated permutations: {(1, 3)}
# query 2497 has repeated permutations: {(5, 7)}
# query 3067 has repeated permutations: {(1, 3)}
# query 3157 has repeated permutations: {(1, 3)}
# query 3517 has repeated permutations: {(3, 5)}
# query 4432 has repeated permutations: {(3, 5)}
# query 4447 has repeated permutations: {(2, 4)}
# query 4522 has repeated permutations: {(6, 8)}
# query 4957 has repeated permutations: {(10, 12)}
# query 5272 has repeated permutations: {(10, 12)}
# query 5332 has repeated permutations: {(3, 5)}
# query 5587 has repeated permutations: {(21, 23)}
# query 6007 has repeated permutations: {(1, 3)}
# query 6127 has repeated permutations: {(6, 8)}
# query 6397 has repeated permutations: {(3, 5)}
# query 7117 has repeated permutations: {(3, 5)}
# query 7612 has repeated permutations: {(5, 7)}
# query 8017 has repeated permutations: {(29, 31)}
# query 8242 has repeated permutations: {(3, 5)}
# query 9562 has repeated permutations: {(18, 20)}
# query 10087 has repeated permutations: {(5, 7)}
# query 10342 has repeated permutations: {(5, 7)}
# query 10432 has repeated permutations: {(5, 7)}
# query 10762 has repeated permutations: {(6, 8)}
# query 10822 has repeated permutations: {(5, 7)}
# query 10867 has repeated permutations: {(3, 5)}
# query 11032 has repeated permutations: {(0, 2)}
# query 11722 has repeated permutations: {(5, 7)}
# query 12322 has repeated permutations: {(59, 61)}
# query 12772 has repeated permutations: {(0, 2)}
# query 13357 has repeated permutations: {(5, 7)}
# query 13627 has repeated permutations: {(5, 7)}
# query 15022 has repeated permutations: {(3, 5)}
# query 15727 has repeated permutations: {(9, 11)}
# query 16207 has repeated permutations: {(29, 31)}
# query 16387 has repeated permutations: {(10, 12)}
# query 16507 has repeated permutations: {(9, 11)}
# query 16642 has repeated permutations: {(3, 5)}
# query 16702 has repeated permutations: {(2, 4)}
# query 17062 has repeated permutations: {(79, 81)}
# query 17287 has repeated permutations: {(5, 7)}
# query 17302 has repeated permutations: {(9, 11)}
# query 17332 has repeated permutations: {(2, 4)}
# query 17827 has repeated permutations: {(3, 5)}
# query 19012 has repeated permutations: {(5, 7)}
# query 19207 has repeated permutations: {(5, 7)}
# query 19432 has repeated permutations: {(85, 87)}
# query 20242 has repeated permutations: {(1, 3), (18, 20)}
# query 20722 has repeated permutations: {(6, 8)}
# query 20887 has repeated permutations: {(5, 7)}
# query 20917 has repeated permutations: {(3, 5)}
# query 21592 has repeated permutations: {(8, 10)}
# query 22822 has repeated permutations: {(5, 7), (6, 8)}
# query 23242 has repeated permutations: {(9, 11)}
# query 24292 has repeated permutations: {(5, 7)}
# query 24382 has repeated permutations: {(1, 3)}
# query 24532 has repeated permutations: {(3, 5)}
# query 25462 has repeated permutations: {(6, 8)}
# query 25567 has repeated permutations: {(18, 20)}
# query 25672 has repeated permutations: {(5, 7)}
# query 25927 has repeated permutations: {(5, 7)}
# query 26287 has repeated permutations: {(8, 10)}
# query 26332 has repeated permutations: {(4, 6)}
# query 26752 has repeated permutations: {(3, 5)}
# query 27367 has repeated permutations: {(7, 9)}
# query 27457 has repeated permutations: {(3, 5)}
# query 27907 has repeated permutations: {(16, 18)}
# query 28012 has repeated permutations: {(1, 3)}
# query 28297 has repeated permutations: {(5, 7)}
# query 28672 has repeated permutations: {(3, 5)}
# query 28717 has repeated permutations: {(5, 7)}
# query 28762 has repeated permutations: {(3, 5)}
# query 29077 has repeated permutations: {(3, 5)}
# query 29167 has repeated permutations: {(6, 8)}
# query 29437 has repeated permutations: {(5, 7)}

# %%
#
# Define evaluation metric and objective function
#

# current predictions, dataset => name, score, true iff higher means better
def mse_eval(preds, train_data):
    labels = train_data.get_label()
    avg_mse = 0.5 * np.mean( (labels-preds)**2 )
    return METRIC_NAME, avg_mse, False

# current predictions, dataset => first order derivative, second order derivative
def mse_grads(preds, train_data): 
    global queries
    global doc_to_query
    gain, hess = eval_grads(queries, doc_to_query, preds, train_data.get_label().astype(np.double))
    #print(preds)
    #print(np.asarray(gain))
    return np.asarray(gain), np.asarray(hess)

# %%
#
# Train the model
#

params = {
#    'objective':'lambdarank', # what to optimize during training
#    'max_position': 10,      # threshold used in optimizing lamdarank (NDCG)
    'learning_rate': 0.1,
    'num_leaves': 16,
    'min_data_in_leaf': 5,
    'metric': ['ndcg'],# ['None'],      # what to use/print for evaluation
    'ndcg_eval_at': 10
# try printing ndcg and testing
}    

print("training lightgbm...")
start = time.process_time()
lgbm_info = {}
lgbm_model = lightgbm.train(params, train_lgb, num_boost_round=100,
                            #feval = mse_eval,
                            fobj  = mse_grads,
                            valid_sets   = [train_lgb, valid_lgb, test_lgb], 
                            valid_names  = ["train", "valid", "test"],
                            evals_result = lgbm_info,
                            verbose_eval = 10)
print("training took " + str(time.process_time() - start) + " s")
print("done")

# Plot the results
plt.figure(figsize=(9,6), tight_layout=True)
plt.plot(lgbm_info['train'][METRIC_NAME], label='training')
plt.plot(lgbm_info['valid'][METRIC_NAME], label='validation')
plt.plot(lgbm_info['test'][METRIC_NAME], label='test')
plt.grid()
plt.legend()
plt.xlabel("# Trees")
plt.ylabel(METRIC_NAME)
plt.title("Model Error")
# Out:
# training lightgbm...
# [10]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [20]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [30]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [40]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [50]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [60]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [70]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [80]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [90]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# [100]	train's ndcg@10: 0.187832	valid's ndcg@10: 0.191826	test's ndcg@10: 0.190877
# training took 1331.640625 s
# done
# Text(0.5, 1.0, 'Model Error')
