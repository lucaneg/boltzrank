# %% [markdown]
# # BoltzRank #
# ## Luca Negrini - Mat. 956516 ##
# ### From "BoltzRank: Learning to Maximize Expected Ranking Gain" ###
# #### Maxims M. Volkovs, Richard S. Zemel ####

# %% [markdown]
# ------
# #### Initialization ####

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib notebook

# %load_ext cython

# install lightgbm (required only on first run)
# import sys
# !{sys.executable} -m pip install lightgbm

import os
import os.path
import numpy as np
import lightgbm
import matplotlib.pyplot as plt

# see http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_svmlight_file.html
from sklearn.datasets import load_svmlight_file 

# datasets available at: 
# https://www.microsoft.com/en-us/research/project/mslr/
DATASET_FOLDER = "C:/opt/kiis-training/MSLR-WEB10K/Fold1/"
PERM_FOLDER = DATASET_FOLDER + "perms/"
METRIC_NAME = 'Custom-MSE'

# %% [markdown]
# -----
# #### Data loading ####

# %%
def ensureFile(path):
    if not os.path.exists(path) or not os.path.isfile(path):
        raise FileNotFoundError("'" + path + "': no such file")        
    return path

def retrieveFileNames():
    folder = DATASET_FOLDER + '/' if DATASET_FOLDER[-1:] != '/' else DATASET_FOLDER
    train_file = ensureFile(folder + "train.txt")
    valid_file = ensureFile(folder + "vali.txt")
    test_file = ensureFile(folder + "test.txt")
    return train_file, valid_file, test_file

def loadDataset(path):
    return load_svmlight_file(path, query_id=True)

def loadLightGBM(svmlight_dataset):
    query_lens = [sum(1 for _ in group) for key, group in itertools.groupby(svmlight_dataset[2])]
    return lightgbm.Dataset(data=svmlight_dataset[0], label=svmlight_dataset[1], group=query_lens)

# %%
class Query:
    def __init__(self, qid):
        self.qid = qid
        self.labels_to_docs = {}
        self.perms = np.empty((1,1))
        self.probs = np.empty((1,1))
    def addlabel(self, label):
        if not label in self.labels_to_docs:
            self.labels_to_docs[label] = list()
    def adddoc(self, label, doc):
        self.labels_to_docs[label].append(doc)
    def finalize(self):
        self.labels = np.zeros(len(self.labels_to_docs.keys()), dtype=int)
        self.docs = np.empty(len(self.labels_to_docs.keys()), dtype=object)
        i = 0
        totaldocs = 0
        sorteddict = sorted(self.labels_to_docs.items(), reverse = True)
        for label, docs in sorteddict:
            self.labels[i] = label
            self.docs[i] = np.zeros(len(docs), dtype=int)
            for j in range(len(docs)):
                self.docs[i][j] = docs[j]
            i += 1
            totaldocs += len(docs)
        self.alldocs = np.concatenate(self.docs)
        self.flatlabels = np.zeros(totaldocs, dtype=np.double)
        i = 0
        for label, docs in sorteddict:
            for j in range(len(docs)):
                self.flatlabels[i] = label
                i += 1
        del self.labels_to_docs
    def setperms(self, perms):
        self.perms = perms
    def setprobs(self, probs):
        self.probs = probs
    def __repr__(self):  
        return str(self)
    def __str__(self):
        res = "Query " + str(self.qid) + "["
        for i in range(len(self.labels)):
            res += "\n" + str(self.labels[i]) + " -> " + str(self.docs[i])
        res += "]"
        for i in range(len(self.perms)):
            res += "\n[" + str(self.perms[i]) + "] -> " + str(self.probs[i])
        return res

# %%
# parameters:
#  dataset: svmlight_dataset 
#      the datset to process
# returned values:
#  query_to_labels_to_documents: dict(int -> dict(float -> list(int)))
#      a map containing, for each query in the dataset, the documents (row index in the dataset) provided 
#      in the input dataset grouped by label
#  doc_to_query: dict(document -> query)
#      a mapping between document (row index in the dataset) and the relative query
def mapQueryToDocuments(dataset):
    queries = {}
    doc_to_query = {} 
    alllabels = np.negative(np.ones(len(dataset[2]), dtype=np.double))
    for i in range(0, len(dataset[2])):
        if not dataset[2][i] in queries:
            queries[dataset[2][i]] = Query(dataset[2][i])
        query = queries[dataset[2][i]]
        query.addlabel(dataset[1][i])
        query.adddoc(dataset[1][i], i)
        doc_to_query[i] = query.qid
        alllabels[i] = dataset[1][i]
        
    for q in queries.values():
        q.finalize()
    
    return queries, alllabels, doc_to_query

# %% [markdown]
# -----
# #### BoltzRank logic in Cython ####

# %%
# %%cython
#
# from cython.parallel import prange
# from cython import boundscheck, wraparound
#
# # The sign-preserving function introduced in formula (4) and defined in formula (5). The implementation follows
# # the one proposed near the end of Section 4.2.
# #
# # parameters:
# #  x: double
# #      the difference in rankings between the two current documents
# #  m: int
# #      the number of documents available for the current query
# # returned values:
# #  val: double
# #      the result of the function
# @boundscheck(False)
# @wraparound(False)
# cdef double g_q(double x, int m) nogil:
#     return (2 * x) / (m - 1)
#
# # The energy function E(R|S) defined in formula (4). This represents the incompatibility between the
# # given ranking and the given score. More energy means less compatibility
# #
# # parameters:
# #  rank: int[:]
# #      the array of document IDs (row index in the dataset) representing the ranking
# #  scores: double[:]
# #      the array of document scores, score of document i will be retrieved from scores[i]
# # returned values:
# #  val: double
# #      the energy of the ranking w.r.t. the target scores. The lower, the better.
# @boundscheck(False)
# @wraparound(False)
# cdef double energy(int[:] rank, double[:] scores) nogil:
#     cdef int m = len(rank)
#     if m == 1 or m == 0:
#         return 0
#     cdef double factor = 2 / (m * (m - 1))
#     cdef double res = 0
#     cdef int j
#     cdef int k
#     for k in prange(m, schedule='static', num_threads=8):
#         for j in range(k + 1, m):
#             res += g_q(j - k, m) * (scores[rank[j]] - scores[rank[k]])
#     return factor * res
#
# from libc.math cimport exp
#
# # The approximate rank probability P[Rq](R|S) defined in formula (12). This approximates the probability of a ranking
# # given a scoring. Since the effective computation is intractable due to the exponentail number of possible rankings,
# # this is computed through a montecarlo estimate over sample ranking sets
# #
# # parameters:
# #  sampleSet: int[:,:]
# #      the array containing all sample rankings, expresed as arrays of document IDs (row index in the dataset)
# #  rank: int[:]
# #      the ranking whose probability is to be computed, expressed as array of document IDs (row index in the dataset)
# #  scores: double[:]
# #      the scores to be used for the energy computation, score of document i will be retrieved from scores[i]
# # returned values:
# #  val: double
# #      the probability of the given ranking
# @boundscheck(False)
# @wraparound(False)
# cpdef double approx_rank_probability(int[:,:] sampleSet, int[:] rank, double[:] scores) nogil:
#     cdef double prob = exp(-energy(rank, scores))
#     cdef double norm = 0
#     cdef int r
#     for r in prange(len(sampleSet), schedule='static', num_threads=8):
#         norm += exp(-energy(sampleSet[r], scores))
#     return prob / norm
#
# from math import factorial
# import numpy as np
#
# #int[:,:] source, int i, int j, int count, int[:,:] perms
# #return: number of not computed permutations
# @boundscheck(False)
# @wraparound(False)
# def perform_permutation(query, int i, int j, int count, int[:,:] perms, int start):
#     if not i in query.labels or not j in query.labels:
#         # no swapping possible
#         return count, start
#     # find the indexes of the desired labels
#     i = [k for k in range(len(query.labels)) if query.labels[k] == i][0]
#     j = [k for k in range(len(query.labels)) if query.labels[k] == j][0]
#     # find maximum amount of permutations that can be done
#     cdef int _min = min(len(query.docs[i]), len(query.docs[j]))
#     cdef int amount = min(count, _min)
#     # randomly selects the indexes
#     cdef int[:] first = np.random.choice(len(query.docs[i]), amount)
#     cdef int[:] second = np.random.choice(len(query.docs[j]), amount)
#     # perform the single-element permutations
#     cdef int k
#     cdef perm
#     cdef int[:] p
#     for k in range(amount):
#         perm = query.docs.copy()
#         perm[i][first[k]], perm[j][second[k]] = query.docs[j][second[k]], query.docs[i][first[k]]
#         p = np.concatenate(perm)
#         perms[start + k] = p
#     return count - amount, start + amount
#
# import random
#
# @boundscheck(False)
# @wraparound(False)
# cdef bint contained(int[:,:] container, int[:] array) nogil:
#     cdef bint match
#     cdef int i
#     cdef int j
#     for i in prange(len(container), schedule='static', num_threads=8):
#         if container[i][0] == -1 or len(container[i]) != len(array):
#             continue
#         else:
#             match = True
#             for j in range(len(container[i])):
#                 if container[i][j] != array[j]:
#                     match = False
#                     break
#             if match:
#                 return True
#     return False
#
# cdef void setrow(int[:,:] container, int pos, int[:] array) nogil:
#     cdef int i
#     for i in prange(len(container[pos]), schedule='static', num_threads=8):
#         container[pos][i] = array[i]
#
#
# #source: label -> docid*, i: int, j: int, count: int, perms_with_prob: tuple<int> -> float
# #return: number of not computed permutations
# @boundscheck(False)
# @wraparound(False)
# def perform_permutation2(query, int i, int j, int count, int[:,:] perms, int start):
#     if not i in query.labels or not j in query.labels:
#         # no swapping possible
#         return count, start
#     # find the indexes of the desired labels
#     i = [k for k in range(len(query.labels)) if query.labels[k] == i][0]
#     j = [k for k in range(len(query.labels)) if query.labels[k] == j][0]
#     cdef int c = 0
#     cdef int _min = min(len(query.docs[i]), len(query.docs[j]))
#     cdef int amount = max(1, int(_min * .5))
#     limit = factorial(_min) / (factorial(amount) * factorial(_min - amount))
#     cdef int k
#     cdef int d
#     for k in range(count):
#         perm = query.docs.copy()
#         first = random.sample(range(len(query.docs[i])), k=amount)
#         second = random.sample(range(len(query.docs[j])), k=amount)
#         for d in range(len(first)):
#             perm[i][first[d]], perm[j][second[d]] = query.docs[j][second[d]], query.docs[i][first[d]]
#         p = np.concatenate(perm)
#         if not contained(perms, p):
#             setrow(perms, start + c, p)
#             c += 1
#             if c == limit:
#                 return count - c, start + c
#         else:
#             k -= 1
#     return 0, start + c
#
# import itertools
#
# @boundscheck(False)
# @wraparound(False)
# cdef int[:,:] allPerms(int[:] source, long long fact):
#     cdef int i = 0
#     cdef int k
#     perm = itertools.permutations(source)
#     cdef int[:,:] result = np.zeros((fact, len(source)), dtype=int)
#     for p in perm:
#         for k in range(len(p)):
#             result[i][k] = p[k]
#         i += 1
#     return result
#
# RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS = 100
# RANK_SAMPLE_SET_DISTRIBUTIONS = [
#                                 int(.20 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->0
#                                 int(.18 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->1
#                                 int(.14 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->2
#                                 int(.08 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 4->3
#                                 int(.14 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 3->0
#                                 int(.12 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 3->1
#                                 int(.06 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 3->2
#                                 int(.04 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 2->0
#                                 int(.02 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS), # 2->1
#                                 int(.02 * RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS)  # 1->0
#                                 ]
#
# #cdef int[:,:] process_query(int query, double[:] labels, int[:,:] docs, double[:] probs) nogil:
# @boundscheck(False)
# @wraparound(False)
# def process_query(query, alllables):
#     cdef int carry = 0
#     fact = factorial(len(query.alldocs))
#     s = " (" + str(RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS) + " permutations computed)"
#     cdef perms
#     cdef int last = 0
#     if fact <= RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS:
#         # evaluate all possible permutations, each one representing a different ranking
#         perms = allPerms(query.alldocs, fact)
#         s = " (all " + str(fact) + " permutations computed)"
#     else:
#         perms = np.negative(np.ones((RANK_SAMPLE_SET_MAX_QUERY_PERMUTATIONS, len(query.alldocs)), dtype=int))
#         # switch the labels of the documents, then sort the documents by label to obtain a ranking
#         carry, last = perform_permutation2(query, 4, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[0], perms, last)
#         carry, last = perform_permutation2(query, 4, 1, RANK_SAMPLE_SET_DISTRIBUTIONS[1] + carry, perms, last)
#         carry, last = perform_permutation2(query, 4, 2, RANK_SAMPLE_SET_DISTRIBUTIONS[2] + carry, perms, last)
#         carry, last = perform_permutation2(query, 4, 3, RANK_SAMPLE_SET_DISTRIBUTIONS[3] + carry, perms, last)
#         carry, last = perform_permutation2(query, 3, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[4] + carry, perms, last)
#         carry, last = perform_permutation2(query, 3, 1, RANK_SAMPLE_SET_DISTRIBUTIONS[5] + carry, perms, last)
#         carry, last = perform_permutation2(query, 3, 2, RANK_SAMPLE_SET_DISTRIBUTIONS[6] + carry, perms, last)
#         carry, last = perform_permutation2(query, 2, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[7] + carry, perms, last)
#         carry, last = perform_permutation2(query, 2, 1, RANK_SAMPLE_SET_DISTRIBUTIONS[8] + carry, perms, last)
#         carry, last = perform_permutation2(query, 1, 0, RANK_SAMPLE_SET_DISTRIBUTIONS[9] + carry, perms, last)
#         if carry != 0:
#             if not query.alldocs in perms:
#                 perms[last] = query.alldocs
#                 s = " (missing " + str(carry - 1) + " permutations - considering also dataset ranking)"
#             else:
#                 s = " (missing " + str(carry) + " permutations) "
#         perms = perms[perms.max(axis=1)>=0]
#     cdef double[:] probs = np.zeros(len(perms))
#     cdef int i
#     for i in range(len(perms)):
#         probs[i] = approx_rank_probability(perms, perms[i], alllables)
#     query.setperms(perms)
#     query.setprobs(probs)
#     print("query " + str(query.qid) + " done " + s)
#     return query
#
# from libc.math cimport log
#
# @boundscheck(False)
# @wraparound(False)
# cpdef double cross_entropy(int[:,:] perms, double[:] probs, double[:] scores) nogil:
#     cdef double result = 0
#     cdef int i
#     for i in prange(len(perms), schedule='static', num_threads=8):
#         result += probs[i] * log(approx_rank_probability(perms, perms[i], scores))
#     return -result
# Out:
# warning: C:\Users\NegriniL\.ipython\cython\_cython_magic_c02287dfbbcc9b7856f8e989d29f3526.pyx:128:33: Use boundscheck(False) for faster access
# warning: C:\Users\NegriniL\.ipython\cython\_cython_magic_c02287dfbbcc9b7856f8e989d29f3526.pyx:128:22: Use boundscheck(False) for faster access

# %%
train_file, valid_file, test_file = retrieveFileNames()

print("training file: " + train_file)
print("validation file: " + valid_file)
print("test file: " + test_file)
    
print("loading datasets... ")
import time
start = time.process_time()
train_dataset = loadDataset(train_file)
print("train dataset loading took " + str(time.process_time() - start) + " s")
start = time.process_time()
valid_dataset = loadDataset(valid_file)
print("validation dataset loading took " + str(time.process_time() - start) + " s")
start = time.process_time()
test_dataset = loadDataset(test_file)
print("test dataset loading took " + str(time.process_time() - start) + " s")

import itertools
print("converting datasets to LightGBM format... ")
train_lgb = loadLightGBM(train_dataset)
valid_lgb = loadLightGBM(valid_dataset)
test_lgb = loadLightGBM(test_dataset)

print("done")
# Out:
# training file: C:/opt/kiis-training/MSLR-WEB10K/Fold1/train.txt
# validation file: C:/opt/kiis-training/MSLR-WEB10K/Fold1/vali.txt
# test file: C:/opt/kiis-training/MSLR-WEB10K/Fold1/test.txt
# loading datasets...
# train dataset loading took 67.09375 s
# validation dataset loading took 22.375 s
# test dataset loading took 21.953125 s
# converting datasets to LightGBM format...
# done

# %%
print("creating query-documents mappings...")
queries, alllables, doc_to_query = mapQueryToDocuments(train_dataset)
print("done")

import multiprocessing
from joblib import Parallel, delayed, parallel_backend
print("creating sample sets...")
start = time.process_time()

#num_cores = multiprocessing.cpu_count()
#with parallel_backend('threading', n_jobs=num_cores):
#    result_list = Parallel()(delayed(process_query)(query) for query in queries.values())
#result_list = Parallel(n_jobs=num_cores)(delayed(process_query)(query) for query in queries.values())
#for q in result_list:
    #queries[q.qid] = q
for q in queries.values():
    queries[q.qid] = process_query(q, alllables)
print("sample set creation took " + str(time.process_time() - start) + " s")
print("done")
# Out:
# creating query-documents mappings...
# done
# creating sample sets...
# query 1 done  (100 permutations computed)
# query 16 done  (100 permutations computed)
# query 31 done  (100 permutations computed)
# query 46 done  (100 permutations computed)
# query 61 done  (100 permutations computed)
# query 76 done  (100 permutations computed)
# query 91 done  (100 permutations computed)
# query 106 done  (missing 99 permutations - considering also dataset ranking)
# query 121 done  (100 permutations computed)
# query 136 done  (100 permutations computed)
# query 151 done  (100 permutations computed)
# query 166 done  (100 permutations computed)
# query 181 done  (100 permutations computed)
# query 196 done  (100 permutations computed)
# query 211 done  (missing 20 permutations)
# query 226 done  (100 permutations computed)
# query 241 done  (100 permutations computed)
# query 256 done  (100 permutations computed)
# query 271 done  (100 permutations computed)
# query 286 done  (missing 99 permutations - considering also dataset ranking)
# query 301 done  (100 permutations computed)
# query 316 done  (missing 78 permutations)
# query 331 done  (100 permutations computed)
# query 346 done  (100 permutations computed)
# query 361 done  (100 permutations computed)
# query 376 done  (100 permutations computed)
# query 391 done  (100 permutations computed)
# query 406 done  (100 permutations computed)
# query 421 done  (100 permutations computed)
# query 436 done  (100 permutations computed)
# query 451 done  (missing 93 permutations)
# query 466 done  (100 permutations computed)
# query 481 done  (100 permutations computed)
# query 496 done  (100 permutations computed)
# query 511 done  (100 permutations computed)
# query 526 done  (100 permutations computed)
# query 541 done  (100 permutations computed)
# query 556 done  (100 permutations computed)
# query 571 done  (100 permutations computed)
# query 586 done  (100 permutations computed)
# query 601 done  (missing 78 permutations)
# query 616 done  (100 permutations computed)
# query 631 done  (100 permutations computed)
# query 646 done  (100 permutations computed)
# query 661 done  (100 permutations computed)
# query 676 done  (100 permutations computed)
# query 691 done  (100 permutations computed)
# query 706 done  (100 permutations computed)
# query 721 done  (100 permutations computed)
# query 736 done  (100 permutations computed)
# query 751 done  (missing 94 permutations)
# query 766 done  (100 permutations computed)
# query 781 done  (missing 89 permutations)
# query 796 done  (100 permutations computed)
# query 811 done  (100 permutations computed)
# query 826 done  (100 permutations computed)
# query 841 done  (100 permutations computed)
# query 856 done  (100 permutations computed)
# query 871 done  (100 permutations computed)
# query 886 done  (100 permutations computed)
# query 901 done  (100 permutations computed)
# query 916 done  (missing 99 permutations - considering also dataset ranking)
# query 931 done  (100 permutations computed)
# query 946 done  (100 permutations computed)
# query 961 done  (100 permutations computed)
# query 976 done  (100 permutations computed)
# query 991 done  (100 permutations computed)
# query 1006 done  (100 permutations computed)
# query 1021 done  (100 permutations computed)
# query 1036 done  (100 permutations computed)
# query 1051 done  (100 permutations computed)
# query 1066 done  (100 permutations computed)
# query 1081 done  (100 permutations computed)
# query 1096 done  (100 permutations computed)
# query 1111 done  (100 permutations computed)
# query 1126 done  (100 permutations computed)
# query 1141 done  (100 permutations computed)
# query 1156 done  (100 permutations computed)
# query 1171 done  (100 permutations computed)
# query 1186 done  (100 permutations computed)
# query 1201 done  (100 permutations computed)
# query 1216 done  (100 permutations computed)
# query 1231 done  (100 permutations computed)
# query 1246 done  (100 permutations computed)
# query 1261 done  (100 permutations computed)
# query 1276 done  (100 permutations computed)
# query 1291 done  (100 permutations computed)
# query 1306 done  (100 permutations computed)
# query 1321 done  (100 permutations computed)
# query 1336 done  (100 permutations computed)
# query 1351 done  (missing 74 permutations)
# query 1366 done  (100 permutations computed)
# query 1381 done  (100 permutations computed)
# query 1396 done  (100 permutations computed)
# query 1411 done  (100 permutations computed)
# query 1426 done  (missing 90 permutations)
# query 1441 done  (missing 76 permutations)
# query 1456 done  (100 permutations computed)
# query 1471 done  (missing 83 permutations)
# query 1486 done  (100 permutations computed)
# query 1501 done  (100 permutations computed)
# query 1516 done  (100 permutations computed)
# query 1531 done  (100 permutations computed)
# query 1546 done  (missing 94 permutations)
# query 1561 done  (100 permutations computed)
# query 1576 done  (100 permutations computed)
# query 1591 done  (100 permutations computed)
# query 1606 done  (missing 78 permutations)
# query 1621 done  (100 permutations computed)
# query 1636 done  (100 permutations computed)
# query 1651 done  (100 permutations computed)
# query 1666 done  (100 permutations computed)
# query 1681 done  (100 permutations computed)
# query 1696 done  (100 permutations computed)
# query 1711 done  (missing 94 permutations)
# query 1726 done  (100 permutations computed)
# query 1741 done  (100 permutations computed)
# query 1756 done  (100 permutations computed)
# query 1771 done  (100 permutations computed)
# query 1786 done  (100 permutations computed)
# query 1801 done  (100 permutations computed)
# query 1816 done  (100 permutations computed)
# query 1831 done  (100 permutations computed)
# query 1846 done  (100 permutations computed)
# query 1861 done  (100 permutations computed)
# query 1876 done  (100 permutations computed)
# query 1891 done  (100 permutations computed)
# query 1906 done  (100 permutations computed)
# query 1921 done  (missing 97 permutations)
# query 1936 done  (100 permutations computed)
# query 1951 done  (100 permutations computed)
# query 1966 done  (100 permutations computed)
# query 1981 done  (missing 56 permutations)
# query 1996 done  (100 permutations computed)
# query 2011 done  (100 permutations computed)
# query 2026 done  (100 permutations computed)
# query 2041 done  (100 permutations computed)
# query 2056 done  (100 permutations computed)
# query 2071 done  (100 permutations computed)
# query 2086 done  (100 permutations computed)
# query 2101 done  (100 permutations computed)
# query 2116 done  (missing 94 permutations)
# query 2131 done  (missing 18 permutations)
# query 2146 done  (100 permutations computed)
# query 2161 done  (100 permutations computed)
# query 2176 done  (100 permutations computed)
# query 2191 done  (100 permutations computed)
# query 2206 done  (100 permutations computed)
# query 2221 done  (100 permutations computed)
# query 2236 done  (100 permutations computed)
# query 2251 done  (100 permutations computed)
# query 2266 done  (100 permutations computed)
# query 2281 done  (missing 99 permutations - considering also dataset ranking)
# query 2296 done  (100 permutations computed)
# query 2311 done  (100 permutations computed)
# query 2326 done  (100 permutations computed)
# query 2341 done  (100 permutations computed)
# query 2356 done  (100 permutations computed)
# query 2371 done  (100 permutations computed)
# query 2386 done  (100 permutations computed)
# query 2401 done  (100 permutations computed)
# query 2416 done  (100 permutations computed)
# query 2431 done  (missing 28 permutations)
# query 2446 done  (100 permutations computed)
# query 2461 done  (missing 94 permutations)
# query 2476 done  (100 permutations computed)
# query 2491 done  (100 permutations computed)
# query 2506 done  (100 permutations computed)
# query 2521 done  (100 permutations computed)
# query 2536 done  (missing 93 permutations)
# query 2551 done  (100 permutations computed)
# query 2566 done  (100 permutations computed)
# query 2581 done  (100 permutations computed)
# query 2596 done  (100 permutations computed)
# query 2611 done  (missing 99 permutations)
# query 2626 done  (100 permutations computed)
# query 2641 done  (100 permutations computed)
# query 2656 done  (100 permutations computed)
# query 2671 done  (100 permutations computed)
# query 2686 done  (100 permutations computed)
# query 2701 done  (missing 72 permutations)
# query 2716 done  (100 permutations computed)
# query 2731 done  (100 permutations computed)
# query 2746 done  (100 permutations computed)
# query 2761 done  (100 permutations computed)
# query 2776 done  (100 permutations computed)
# query 2791 done  (100 permutations computed)
# query 2806 done  (100 permutations computed)
# query 2821 done  (100 permutations computed)
# query 2836 done  (100 permutations computed)
# query 2851 done  (100 permutations computed)
# query 2866 done  (missing 93 permutations)
# query 2881 done  (100 permutations computed)
# query 2896 done  (100 permutations computed)
# query 2911 done  (100 permutations computed)
# query 2926 done  (100 permutations computed)
# query 2941 done  (100 permutations computed)
# query 2956 done  (100 permutations computed)
# query 2971 done  (100 permutations computed)
# query 2986 done  (100 permutations computed)
# query 3001 done  (100 permutations computed)
# query 3016 done  (100 permutations computed)
# query 3031 done  (100 permutations computed)
# query 3046 done  (100 permutations computed)
# query 3061 done  (100 permutations computed)
# query 3076 done  (100 permutations computed)
# query 3091 done  (100 permutations computed)
# query 3106 done  (100 permutations computed)
# query 3121 done  (100 permutations computed)
# query 3136 done  (missing 90 permutations)
# query 3151 done  (100 permutations computed)
# query 3166 done  (missing 94 permutations)
# query 3181 done  (100 permutations computed)
# query 3196 done  (100 permutations computed)
# query 3211 done  (100 permutations computed)
# query 3226 done  (missing 99 permutations - considering also dataset ranking)
# query 3241 done  (100 permutations computed)
# query 3256 done  (100 permutations computed)
# query 3271 done  (100 permutations computed)
# query 3286 done  (100 permutations computed)
# query 3301 done  (missing 80 permutations)
# query 3316 done  (100 permutations computed)
# query 3331 done  (100 permutations computed)
# query 3346 done  (100 permutations computed)
# query 3361 done  (100 permutations computed)
# query 3376 done  (100 permutations computed)
# query 3391 done  (100 permutations computed)
# query 3406 done  (100 permutations computed)
# query 3421 done  (100 permutations computed)
# query 3436 done  (100 permutations computed)
# query 3451 done  (100 permutations computed)
# query 3466 done  (100 permutations computed)
# query 3481 done  (100 permutations computed)
# query 3496 done  (100 permutations computed)
# query 3511 done  (100 permutations computed)
# query 3526 done  (100 permutations computed)
# query 3541 done  (100 permutations computed)
# query 3556 done  (100 permutations computed)
# query 3571 done  (100 permutations computed)
# query 3586 done  (100 permutations computed)
# query 3601 done  (100 permutations computed)
# query 3616 done  (100 permutations computed)
# query 3631 done  (100 permutations computed)
# query 3646 done  (100 permutations computed)
# query 3661 done  (100 permutations computed)
# query 3676 done  (100 permutations computed)
# query 3691 done  (100 permutations computed)
# query 3706 done  (100 permutations computed)
# query 3721 done  (100 permutations computed)
# query 3736 done  (100 permutations computed)
# query 3751 done  (100 permutations computed)
# query 3766 done  (100 permutations computed)
# query 3781 done  (100 permutations computed)
# query 3796 done  (100 permutations computed)
# query 3811 done  (100 permutations computed)
# query 3826 done  (100 permutations computed)
# query 3841 done  (100 permutations computed)
# query 3856 done  (100 permutations computed)
# query 3871 done  (100 permutations computed)
# query 3886 done  (100 permutations computed)
# query 3901 done  (100 permutations computed)
# query 3916 done  (missing 23 permutations)
# query 3931 done  (missing 95 permutations)
# query 3946 done  (100 permutations computed)
# query 3961 done  (100 permutations computed)
# query 3976 done  (100 permutations computed)
# query 3991 done  (100 permutations computed)
# query 4006 done  (100 permutations computed)
# query 4021 done  (100 permutations computed)
# query 4036 done  (100 permutations computed)
# query 4051 done  (missing 99 permutations)
# query 4066 done  (100 permutations computed)
# query 4081 done  (100 permutations computed)
# query 4096 done  (100 permutations computed)
# query 4111 done  (100 permutations computed)
# query 4126 done  (100 permutations computed)
# query 4141 done  (100 permutations computed)
# query 4156 done  (100 permutations computed)
# query 4171 done  (100 permutations computed)
# query 4186 done  (100 permutations computed)
# query 4201 done  (100 permutations computed)
# query 4216 done  (100 permutations computed)
# query 4231 done  (100 permutations computed)
# query 4246 done  (missing 96 permutations)
# query 4261 done  (100 permutations computed)
# query 4276 done  (100 permutations computed)
# query 4291 done  (100 permutations computed)
# query 4306 done  (100 permutations computed)
# query 4321 done  (100 permutations computed)
# query 4336 done  (100 permutations computed)
# query 4351 done  (100 permutations computed)
# query 4366 done  (missing 90 permutations)
# query 4381 done  (100 permutations computed)
# query 4396 done  (100 permutations computed)
# query 4411 done  (100 permutations computed)
# query 4426 done  (100 permutations computed)
# query 4441 done  (100 permutations computed)
# query 4456 done  (100 permutations computed)
# query 4471 done  (100 permutations computed)
# query 4486 done  (100 permutations computed)
# query 4501 done  (100 permutations computed)
# query 4516 done  (100 permutations computed)
# query 4531 done  (100 permutations computed)
# query 4546 done  (100 permutations computed)
# query 4561 done  (100 permutations computed)
# query 4576 done  (100 permutations computed)
# query 4591 done  (100 permutations computed)
# query 4606 done  (100 permutations computed)
# query 4621 done  (missing 97 permutations)
# query 4636 done  (100 permutations computed)
# query 4651 done  (100 permutations computed)
# query 4666 done  (100 permutations computed)
# query 4681 done  (100 permutations computed)
# query 4696 done  (100 permutations computed)
# query 4711 done  (100 permutations computed)
# query 4726 done  (100 permutations computed)
# query 4741 done  (100 permutations computed)
# query 4756 done  (100 permutations computed)
# query 4771 done  (100 permutations computed)
# query 4786 done  (100 permutations computed)
# query 4801 done  (100 permutations computed)
# query 4816 done  (100 permutations computed)
# query 4831 done  (100 permutations computed)
# query 4846 done  (100 permutations computed)
# query 4861 done  (100 permutations computed)
# query 4876 done  (100 permutations computed)
# query 4891 done  (100 permutations computed)
# query 4906 done  (100 permutations computed)
# query 4921 done  (100 permutations computed)
# query 4936 done  (100 permutations computed)
# query 4951 done  (100 permutations computed)
# query 4966 done  (100 permutations computed)
# query 4981 done  (100 permutations computed)
# query 4996 done  (missing 97 permutations)
# query 5011 done  (100 permutations computed)
# query 5026 done  (missing 84 permutations)
# query 5041 done  (100 permutations computed)
# query 5056 done  (100 permutations computed)
# query 5071 done  (100 permutations computed)
# query 5086 done  (100 permutations computed)
# query 5101 done  (100 permutations computed)
# query 5116 done  (100 permutations computed)
# query 5131 done  (100 permutations computed)
# query 5146 done  (100 permutations computed)
# query 5161 done  (100 permutations computed)
# query 5176 done  (missing 30 permutations)
# query 5191 done  (100 permutations computed)
# query 5206 done  (missing 92 permutations)
# query 5221 done  (100 permutations computed)
# query 5236 done  (100 permutations computed)
# query 5251 done  (100 permutations computed)
# query 5266 done  (100 permutations computed)
# query 5281 done  (missing 53 permutations)
# query 5296 done  (missing 95 permutations)
# query 5311 done  (100 permutations computed)
# query 5326 done  (missing 90 permutations)
# query 5341 done  (missing 95 permutations)
# query 5356 done  (100 permutations computed)
# query 5371 done  (100 permutations computed)
# query 5386 done  (100 permutations computed)
# query 5401 done  (100 permutations computed)
# query 5416 done  (missing 94 permutations)
# query 5431 done  (100 permutations computed)
# query 5446 done  (100 permutations computed)
# query 5461 done  (100 permutations computed)
# query 5476 done  (missing 75 permutations)
# query 5491 done  (100 permutations computed)
# query 5506 done  (100 permutations computed)
# query 5521 done  (100 permutations computed)
# query 5536 done  (100 permutations computed)
# query 5551 done  (100 permutations computed)
# query 5566 done  (100 permutations computed)
# query 5581 done  (100 permutations computed)
# query 5596 done  (missing 76 permutations)
# query 5611 done  (missing 91 permutations)
# query 5626 done  (100 permutations computed)
# query 5641 done  (100 permutations computed)
# query 5656 done  (missing 10 permutations)
# query 5671 done  (missing 99 permutations)
# query 5686 done  (100 permutations computed)
# query 5701 done  (100 permutations computed)
# query 5716 done  (100 permutations computed)
# query 5731 done  (100 permutations computed)
# query 5746 done  (100 permutations computed)
# query 5761 done  (100 permutations computed)
# query 5776 done  (100 permutations computed)
# query 5791 done  (100 permutations computed)
# query 5806 done  (100 permutations computed)
# query 5821 done  (100 permutations computed)
# query 5836 done  (100 permutations computed)
# query 5851 done  (100 permutations computed)
# query 5866 done  (100 permutations computed)
# query 5881 done  (100 permutations computed)
# query 5896 done  (100 permutations computed)
# query 5911 done  (100 permutations computed)
# query 5926 done  (missing 59 permutations)
# query 5941 done  (100 permutations computed)
# query 5956 done  (missing 28 permutations)
# query 5971 done  (100 permutations computed)
# query 5986 done  (100 permutations computed)
# query 6001 done  (100 permutations computed)
# query 6016 done  (100 permutations computed)
# query 6031 done  (100 permutations computed)
# query 6046 done  (100 permutations computed)
# query 6061 done  (100 permutations computed)
# query 6076 done  (100 permutations computed)
# query 6091 done  (100 permutations computed)
# query 6106 done  (100 permutations computed)
# query 6121 done  (100 permutations computed)
# query 6136 done  (missing 99 permutations)
# query 6151 done  (missing 30 permutations)
# query 6166 done  (missing 96 permutations)
# query 6181 done  (100 permutations computed)
# query 6196 done  (100 permutations computed)
# query 6211 done  (100 permutations computed)
# query 6226 done  (100 permutations computed)
# query 6241 done  (100 permutations computed)
# query 6256 done  (missing 94 permutations)
# query 6271 done  (missing 99 permutations)
# query 6286 done  (100 permutations computed)
# query 6301 done  (100 permutations computed)
# query 6316 done  (100 permutations computed)
# query 6331 done  (100 permutations computed)
# query 6346 done  (100 permutations computed)
# query 6361 done  (missing 99 permutations)
# query 6376 done  (100 permutations computed)
# query 6391 done  (100 permutations computed)
# query 6406 done  (100 permutations computed)
# query 6421 done  (100 permutations computed)
# query 6436 done  (100 permutations computed)
# query 6451 done  (100 permutations computed)
# query 6466 done  (100 permutations computed)
# query 6481 done  (100 permutations computed)
# query 6496 done  (100 permutations computed)
# query 6511 done  (100 permutations computed)
# query 6526 done  (100 permutations computed)
# query 6541 done  (100 permutations computed)
# query 6556 done  (100 permutations computed)
# query 6571 done  (100 permutations computed)
# query 6586 done  (missing 97 permutations)
# query 6601 done  (100 permutations computed)
# query 6616 done  (100 permutations computed)
# query 6631 done  (100 permutations computed)
# query 6646 done  (100 permutations computed)
# query 6661 done  (100 permutations computed)
# query 6676 done  (100 permutations computed)
# query 6691 done  (100 permutations computed)
# query 6706 done  (missing 88 permutations)
# query 6721 done  (100 permutations computed)
# query 6736 done  (100 permutations computed)
# query 6751 done  (100 permutations computed)
# query 6766 done  (100 permutations computed)
# query 6781 done  (missing 68 permutations)
# query 6796 done  (100 permutations computed)
# query 6811 done  (100 permutations computed)
# query 6826 done  (100 permutations computed)
# query 6841 done  (100 permutations computed)
# query 6856 done  (100 permutations computed)
# query 6871 done  (100 permutations computed)
# query 6886 done  (100 permutations computed)
# query 6901 done  (100 permutations computed)
# query 6916 done  (100 permutations computed)
# query 6931 done  (100 permutations computed)
# query 6946 done  (missing 78 permutations)
# query 6961 done  (100 permutations computed)
# query 6976 done  (100 permutations computed)
# query 6991 done  (100 permutations computed)
# query 7006 done  (100 permutations computed)
# query 7021 done  (missing 97 permutations)
# query 7036 done  (100 permutations computed)
# query 7051 done  (100 permutations computed)
# query 7066 done  (100 permutations computed)
# query 7081 done  (missing 26 permutations)
# query 7096 done  (100 permutations computed)
# query 7111 done  (100 permutations computed)
# query 7126 done  (100 permutations computed)
# query 7141 done  (missing 99 permutations)
# query 7156 done  (100 permutations computed)
# query 7171 done  (100 permutations computed)
# query 7186 done  (100 permutations computed)
# query 7201 done  (100 permutations computed)
# query 7216 done  (100 permutations computed)
# query 7231 done  (100 permutations computed)
# query 7246 done  (100 permutations computed)
# query 7261 done  (100 permutations computed)
# query 7276 done  (100 permutations computed)
# query 7291 done  (100 permutations computed)
# query 7306 done  (100 permutations computed)
# query 7321 done  (100 permutations computed)
# query 7336 done  (missing 63 permutations)
# query 7351 done  (100 permutations computed)
# query 7366 done  (100 permutations computed)
# query 7381 done  (100 permutations computed)
# query 7396 done  (100 permutations computed)
# query 7411 done  (100 permutations computed)
# query 7426 done  (100 permutations computed)
# query 7441 done  (missing 98 permutations)
# query 7456 done  (100 permutations computed)
# query 7471 done  (100 permutations computed)
# query 7486 done  (100 permutations computed)
# query 7501 done  (100 permutations computed)
# query 7516 done  (100 permutations computed)
# query 7531 done  (100 permutations computed)
# query 7546 done  (100 permutations computed)
# query 7561 done  (100 permutations computed)
# query 7576 done  (missing 99 permutations - considering also dataset ranking)
# query 7591 done  (100 permutations computed)
# query 7606 done  (100 permutations computed)
# query 7621 done  (100 permutations computed)
# query 7636 done  (100 permutations computed)
# query 7651 done  (100 permutations computed)
# query 7666 done  (100 permutations computed)
# query 7681 done  (100 permutations computed)
# query 7696 done  (100 permutations computed)
# query 7711 done  (100 permutations computed)
# query 7726 done  (100 permutations computed)
# query 7741 done  (100 permutations computed)
# query 7756 done  (100 permutations computed)
# query 7771 done  (100 permutations computed)
# query 7786 done  (100 permutations computed)
# query 7801 done  (100 permutations computed)
# query 7816 done  (100 permutations computed)
# query 7831 done  (100 permutations computed)
# query 7846 done  (missing 99 permutations)
# query 7861 done  (100 permutations computed)
# query 7876 done  (100 permutations computed)
# query 7891 done  (100 permutations computed)
# query 7906 done  (100 permutations computed)
# query 7921 done  (100 permutations computed)
# query 7936 done  (100 permutations computed)
# query 7951 done  (100 permutations computed)
# query 7966 done  (100 permutations computed)
# query 7981 done  (100 permutations computed)
# query 7996 done  (100 permutations computed)
# query 8011 done  (missing 84 permutations)
# query 8026 done  (100 permutations computed)
# query 8041 done  (100 permutations computed)
# query 8056 done  (100 permutations computed)
# query 8071 done  (100 permutations computed)
# query 8086 done  (100 permutations computed)
# query 8101 done  (100 permutations computed)
# query 8116 done  (100 permutations computed)
# query 8131 done  (100 permutations computed)
# query 8146 done  (100 permutations computed)
# query 8161 done  (100 permutations computed)
# query 8176 done  (100 permutations computed)
# query 8191 done  (100 permutations computed)
# query 8206 done  (100 permutations computed)
# query 8221 done  (100 permutations computed)
# query 8236 done  (100 permutations computed)
# query 8251 done  (100 permutations computed)
# query 8266 done  (100 permutations computed)
# query 8281 done  (100 permutations computed)
# query 8296 done  (100 permutations computed)
# query 8311 done  (100 permutations computed)
# query 8326 done  (missing 63 permutations)
# query 8341 done  (100 permutations computed)
# query 8356 done  (100 permutations computed)
# query 8371 done  (100 permutations computed)
# query 8386 done  (100 permutations computed)
# query 8401 done  (100 permutations computed)
# query 8416 done  (100 permutations computed)
# query 8431 done  (100 permutations computed)
# query 8446 done  (100 permutations computed)
# query 8461 done  (100 permutations computed)
# query 8476 done  (100 permutations computed)
# query 8491 done  (100 permutations computed)
# query 8506 done  (100 permutations computed)
# query 8521 done  (100 permutations computed)
# query 8536 done  (100 permutations computed)
# query 8551 done  (100 permutations computed)
# query 8566 done  (100 permutations computed)
# query 8581 done  (100 permutations computed)
# query 8596 done  (100 permutations computed)
# query 8611 done  (100 permutations computed)
# query 8626 done  (100 permutations computed)
# query 8641 done  (100 permutations computed)
# query 8656 done  (100 permutations computed)
# query 8671 done  (100 permutations computed)
# query 8686 done  (100 permutations computed)
# query 8701 done  (100 permutations computed)
# query 8716 done  (100 permutations computed)
# query 8731 done  (100 permutations computed)
# query 8746 done  (100 permutations computed)
# query 8761 done  (100 permutations computed)
# query 8776 done  (100 permutations computed)
# query 8791 done  (100 permutations computed)
# query 8806 done  (missing 47 permutations)
# query 8821 done  (missing 88 permutations)
# query 8836 done  (100 permutations computed)
# query 8851 done  (100 permutations computed)
# query 8866 done  (missing 94 permutations)
# query 8881 done  (100 permutations computed)
# query 8896 done  (100 permutations computed)
# query 8911 done  (100 permutations computed)
# query 8926 done  (100 permutations computed)
# query 8941 done  (100 permutations computed)
# query 8956 done  (100 permutations computed)
# query 8971 done  (100 permutations computed)
# query 8986 done  (100 permutations computed)
# query 9001 done  (100 permutations computed)
# query 9016 done  (100 permutations computed)
# query 9031 done  (100 permutations computed)
# query 9046 done  (100 permutations computed)
# query 9061 done  (100 permutations computed)
# query 9076 done  (100 permutations computed)
# query 9091 done  (100 permutations computed)
# query 9106 done  (100 permutations computed)
# query 9121 done  (100 permutations computed)
# query 9136 done  (100 permutations computed)
# query 9151 done  (100 permutations computed)
# query 9166 done  (100 permutations computed)
# query 9181 done  (100 permutations computed)
# query 9196 done  (100 permutations computed)
# query 9211 done  (missing 80 permutations)
# query 9226 done  (missing 94 permutations)
# query 9241 done  (100 permutations computed)
# query 9256 done  (100 permutations computed)
# query 9271 done  (100 permutations computed)
# query 9286 done  (100 permutations computed)
# query 9301 done  (100 permutations computed)
# query 9316 done  (100 permutations computed)
# query 9331 done  (100 permutations computed)
# query 9346 done  (100 permutations computed)
# query 9361 done  (missing 99 permutations)
# query 9376 done  (missing 98 permutations)
# query 9391 done  (100 permutations computed)
# query 9406 done  (100 permutations computed)
# query 9421 done  (100 permutations computed)
# query 9436 done  (100 permutations computed)
# query 9451 done  (100 permutations computed)
# query 9466 done  (missing 93 permutations)
# query 9481 done  (100 permutations computed)
# query 9496 done  (missing 78 permutations)
# query 9511 done  (100 permutations computed)
# query 9526 done  (100 permutations computed)
# query 9541 done  (100 permutations computed)
# query 9556 done  (100 permutations computed)
# query 9571 done  (100 permutations computed)
# query 9586 done  (100 permutations computed)
# query 9601 done  (missing 30 permutations)
# query 9616 done  (missing 99 permutations)
# query 9631 done  (100 permutations computed)
# query 9646 done  (100 permutations computed)
# query 9661 done  (100 permutations computed)
# query 9676 done  (100 permutations computed)
# query 9691 done  (100 permutations computed)
# query 9706 done  (100 permutations computed)
# query 9721 done  (100 permutations computed)
# query 9736 done  (100 permutations computed)
# query 9751 done  (100 permutations computed)
# query 9766 done  (100 permutations computed)
# query 9781 done  (100 permutations computed)
# query 9796 done  (100 permutations computed)
# query 9811 done  (100 permutations computed)
# query 9826 done  (missing 99 permutations - considering also dataset ranking)
# query 9841 done  (all 24 permutations computed)
# query 9856 done  (100 permutations computed)
# query 9871 done  (100 permutations computed)
# query 9886 done  (100 permutations computed)
# query 9901 done  (missing 62 permutations)
# query 9916 done  (100 permutations computed)
# query 9931 done  (100 permutations computed)
# query 9946 done  (100 permutations computed)
# query 9961 done  (100 permutations computed)
# query 9976 done  (missing 59 permutations)
# query 9991 done  (100 permutations computed)
# query 10006 done  (100 permutations computed)
# query 10021 done  (100 permutations computed)
# query 10036 done  (100 permutations computed)
# query 10051 done  (100 permutations computed)
# query 10066 done  (100 permutations computed)
# query 10081 done  (100 permutations computed)
# query 10096 done  (100 permutations computed)
# query 10111 done  (100 permutations computed)
# query 10126 done  (100 permutations computed)
# query 10141 done  (100 permutations computed)
# query 10156 done  (all 2 permutations computed)
# query 10171 done  (100 permutations computed)
# query 10186 done  (100 permutations computed)
# query 10201 done  (100 permutations computed)
# query 10216 done  (100 permutations computed)
# query 10231 done  (100 permutations computed)
# query 10246 done  (100 permutations computed)
# query 10261 done  (100 permutations computed)
# query 10276 done  (100 permutations computed)
# query 10291 done  (100 permutations computed)
# query 10306 done  (100 permutations computed)
# query 10321 done  (100 permutations computed)
# query 10336 done  (missing 88 permutations)
# query 10351 done  (missing 99 permutations - considering also dataset ranking)
# query 10366 done  (100 permutations computed)
# query 10381 done  (100 permutations computed)
# query 10396 done  (100 permutations computed)
# query 10411 done  (100 permutations computed)
# query 10426 done  (100 permutations computed)
# query 10441 done  (100 permutations computed)
# query 10456 done  (100 permutations computed)
# query 10471 done  (100 permutations computed)
# query 10486 done  (100 permutations computed)
# query 10501 done  (100 permutations computed)
# query 10516 done  (100 permutations computed)
# query 10531 done  (100 permutations computed)
# query 10546 done  (100 permutations computed)
# query 10561 done  (100 permutations computed)
# query 10576 done  (missing 99 permutations - considering also dataset ranking)
# query 10591 done  (100 permutations computed)
# query 10606 done  (100 permutations computed)
# query 10621 done  (100 permutations computed)
# query 10636 done  (100 permutations computed)
# query 10651 done  (100 permutations computed)
# query 10666 done  (100 permutations computed)
# query 10681 done  (100 permutations computed)
# query 10696 done  (100 permutations computed)
# query 10711 done  (missing 98 permutations)
# query 10726 done  (100 permutations computed)
# query 10741 done  (100 permutations computed)
# query 10756 done  (100 permutations computed)
# query 10771 done  (missing 99 permutations - considering also dataset ranking)
# query 10786 done  (100 permutations computed)
# query 10801 done  (missing 90 permutations)
# query 10816 done  (100 permutations computed)
# query 10831 done  (100 permutations computed)
# query 10846 done  (100 permutations computed)
# query 10861 done  (100 permutations computed)
# query 10876 done  (100 permutations computed)
# query 10891 done  (100 permutations computed)
# query 10906 done  (100 permutations computed)
# query 10921 done  (100 permutations computed)
# query 10936 done  (100 permutations computed)
# query 10951 done  (all 2 permutations computed)
# query 10966 done  (100 permutations computed)
# query 10981 done  (100 permutations computed)
# query 10996 done  (100 permutations computed)
# query 11011 done  (100 permutations computed)
# query 11026 done  (100 permutations computed)
# query 11041 done  (100 permutations computed)
# query 11056 done  (100 permutations computed)
# query 11071 done  (100 permutations computed)
# query 11086 done  (100 permutations computed)
# query 11101 done  (100 permutations computed)
# query 11116 done  (100 permutations computed)
# query 11131 done  (100 permutations computed)
# query 11146 done  (100 permutations computed)
# query 11161 done  (100 permutations computed)
# query 11176 done  (100 permutations computed)
# query 11191 done  (missing 60 permutations)
# query 11206 done  (100 permutations computed)
# query 11221 done  (missing 30 permutations)
# query 11236 done  (missing 98 permutations)
# query 11251 done  (100 permutations computed)
# query 11266 done  (100 permutations computed)
# query 11281 done  (100 permutations computed)
# query 11296 done  (100 permutations computed)
# query 11311 done  (100 permutations computed)
# query 11326 done  (100 permutations computed)
# query 11341 done  (100 permutations computed)
# query 11356 done  (100 permutations computed)
# query 11371 done  (100 permutations computed)
# query 11386 done  (100 permutations computed)
# query 11401 done  (100 permutations computed)
# query 11416 done  (missing 80 permutations)
# query 11431 done  (100 permutations computed)
# query 11446 done  (100 permutations computed)
# query 11461 done  (100 permutations computed)
# query 11476 done  (100 permutations computed)
# query 11491 done  (missing 97 permutations)
# query 11506 done  (100 permutations computed)
# query 11521 done  (100 permutations computed)
# query 11536 done  (100 permutations computed)
# query 11551 done  (missing 97 permutations)
# query 11566 done  (missing 90 permutations)
# query 11581 done  (100 permutations computed)
# query 11596 done  (100 permutations computed)
# query 11611 done  (100 permutations computed)
# query 11626 done  (missing 97 permutations)
# query 11641 done  (100 permutations computed)
# query 11656 done  (100 permutations computed)
# query 11671 done  (100 permutations computed)
# query 11686 done  (missing 88 permutations)
# query 11701 done  (100 permutations computed)
# query 11716 done  (100 permutations computed)
# query 11731 done  (100 permutations computed)
# query 11746 done  (100 permutations computed)
# query 11761 done  (100 permutations computed)
# query 11776 done  (100 permutations computed)
# query 11791 done  (missing 80 permutations)
# query 11806 done  (100 permutations computed)
# query 11821 done  (100 permutations computed)
# query 11836 done  (100 permutations computed)
# query 11851 done  (100 permutations computed)
# query 11866 done  (100 permutations computed)
# query 11881 done  (100 permutations computed)
# query 11896 done  (100 permutations computed)
# query 11911 done  (missing 97 permutations)
# query 11926 done  (100 permutations computed)
# query 11941 done  (100 permutations computed)
# query 11956 done  (100 permutations computed)
# query 11971 done  (100 permutations computed)
# query 11986 done  (100 permutations computed)
# query 12001 done  (100 permutations computed)
# query 12016 done  (missing 78 permutations)
# query 12031 done  (100 permutations computed)
# query 12046 done  (100 permutations computed)
# query 12061 done  (100 permutations computed)
# query 12076 done  (missing 98 permutations)
# query 12091 done  (missing 98 permutations)
# query 12106 done  (100 permutations computed)
# query 12121 done  (100 permutations computed)
# query 12136 done  (100 permutations computed)
# query 12151 done  (100 permutations computed)
# query 12166 done  (missing 26 permutations)
# query 12181 done  (100 permutations computed)
# query 12196 done  (100 permutations computed)
# query 12211 done  (100 permutations computed)
# query 12226 done  (100 permutations computed)
# query 12241 done  (100 permutations computed)
# query 12256 done  (100 permutations computed)
# query 12271 done  (missing 15 permutations)
# query 12286 done  (100 permutations computed)
# query 12301 done  (100 permutations computed)
# query 12316 done  (100 permutations computed)
# query 12331 done  (100 permutations computed)
# query 12346 done  (100 permutations computed)
# query 12361 done  (100 permutations computed)
# query 12376 done  (missing 74 permutations)
# query 12391 done  (missing 30 permutations)
# query 12406 done  (100 permutations computed)
# query 12421 done  (100 permutations computed)
# query 12436 done  (100 permutations computed)
# query 12451 done  (100 permutations computed)
# query 12466 done  (100 permutations computed)
# query 12481 done  (100 permutations computed)
# query 12496 done  (100 permutations computed)
# query 12511 done  (100 permutations computed)
# query 12526 done  (100 permutations computed)
# query 12541 done  (100 permutations computed)
# query 12556 done  (100 permutations computed)
# query 12571 done  (100 permutations computed)
# query 12586 done  (100 permutations computed)
# query 12601 done  (100 permutations computed)
# query 12616 done  (100 permutations computed)
# query 12631 done  (100 permutations computed)
# query 12646 done  (100 permutations computed)
# query 12661 done  (100 permutations computed)
# query 12676 done  (100 permutations computed)
# query 12691 done  (100 permutations computed)
# query 12706 done  (100 permutations computed)
# query 12721 done  (100 permutations computed)
# query 12736 done  (100 permutations computed)
# query 12751 done  (all 24 permutations computed)
# query 12766 done  (100 permutations computed)
# query 12781 done  (100 permutations computed)
# query 12796 done  (missing 94 permutations)
# query 12811 done  (missing 99 permutations - considering also dataset ranking)
# query 12826 done  (100 permutations computed)
# query 12841 done  (100 permutations computed)
# query 12856 done  (100 permutations computed)
# query 12871 done  (100 permutations computed)
# query 12886 done  (100 permutations computed)
# query 12901 done  (100 permutations computed)
# query 12916 done  (100 permutations computed)
# query 12931 done  (100 permutations computed)
# query 12946 done  (100 permutations computed)
# query 12961 done  (100 permutations computed)
# query 12976 done  (100 permutations computed)
# query 12991 done  (100 permutations computed)
# query 13006 done  (100 permutations computed)
# query 13021 done  (100 permutations computed)
# query 13036 done  (100 permutations computed)
# query 13051 done  (100 permutations computed)
# query 13066 done  (100 permutations computed)
# query 13081 done  (100 permutations computed)
# query 13096 done  (100 permutations computed)
# query 13111 done  (100 permutations computed)
# query 13126 done  (100 permutations computed)
# query 13141 done  (missing 98 permutations)
# query 13156 done  (100 permutations computed)
# query 13171 done  (100 permutations computed)
# query 13186 done  (100 permutations computed)
# query 13201 done  (100 permutations computed)
# query 13216 done  (100 permutations computed)
# query 13231 done  (100 permutations computed)
# query 13246 done  (100 permutations computed)
# query 13261 done  (100 permutations computed)
# query 13276 done  (100 permutations computed)
# query 13291 done  (100 permutations computed)
# query 13306 done  (100 permutations computed)
# query 13321 done  (100 permutations computed)
# query 13336 done  (100 permutations computed)
# query 13351 done  (100 permutations computed)
# query 13366 done  (100 permutations computed)
# query 13381 done  (100 permutations computed)
# query 13396 done  (100 permutations computed)
# query 13411 done  (missing 78 permutations)
# query 13426 done  (100 permutations computed)
# query 13441 done  (100 permutations computed)
# query 13456 done  (100 permutations computed)
# query 13471 done  (missing 90 permutations)
# query 13486 done  (100 permutations computed)
# query 13501 done  (100 permutations computed)
# query 13516 done  (100 permutations computed)
# query 13531 done  (100 permutations computed)
# query 13546 done  (100 permutations computed)
# query 13561 done  (100 permutations computed)
# query 13576 done  (missing 92 permutations)
# query 13591 done  (100 permutations computed)
# query 13606 done  (all 24 permutations computed)
# query 13621 done  (100 permutations computed)
# query 13636 done  (100 permutations computed)
# query 13651 done  (100 permutations computed)
# query 13666 done  (100 permutations computed)
# query 13681 done  (100 permutations computed)
# query 13696 done  (100 permutations computed)
# query 13711 done  (missing 99 permutations - considering also dataset ranking)
# query 13726 done  (all 2 permutations computed)
# query 13741 done  (missing 80 permutations)
# query 13756 done  (100 permutations computed)
# query 13771 done  (100 permutations computed)
# query 13786 done  (100 permutations computed)
# query 13801 done  (100 permutations computed)
# query 13816 done  (missing 99 permutations - considering also dataset ranking)
# query 13831 done  (100 permutations computed)
# query 13846 done  (100 permutations computed)
# query 13861 done  (100 permutations computed)
# query 13876 done  (100 permutations computed)
# query 13891 done  (100 permutations computed)
# query 13906 done  (100 permutations computed)
# query 13921 done  (100 permutations computed)
# query 13936 done  (100 permutations computed)
# query 13951 done  (100 permutations computed)
# query 13966 done  (100 permutations computed)
# query 13981 done  (100 permutations computed)
# query 13996 done  (100 permutations computed)
# query 14011 done  (100 permutations computed)
# query 14026 done  (100 permutations computed)
# query 14041 done  (100 permutations computed)
# query 14056 done  (100 permutations computed)
# query 14071 done  (missing 92 permutations)
# query 14086 done  (100 permutations computed)
# query 14101 done  (100 permutations computed)
# query 14116 done  (100 permutations computed)
# query 14131 done  (100 permutations computed)
# query 14146 done  (100 permutations computed)
# query 14161 done  (100 permutations computed)
# query 14176 done  (100 permutations computed)
# query 14191 done  (100 permutations computed)
# query 14206 done  (100 permutations computed)
# query 14221 done  (100 permutations computed)
# query 14236 done  (100 permutations computed)
# query 14251 done  (100 permutations computed)
# query 14266 done  (100 permutations computed)
# query 14281 done  (100 permutations computed)
# query 14296 done  (100 permutations computed)
# query 14311 done  (100 permutations computed)
# query 14326 done  (100 permutations computed)
# query 14341 done  (100 permutations computed)
# query 14356 done  (100 permutations computed)
# query 14371 done  (100 permutations computed)
# query 14386 done  (100 permutations computed)
# query 14401 done  (100 permutations computed)
# query 14416 done  (100 permutations computed)
# query 14431 done  (missing 58 permutations)
# query 14446 done  (missing 99 permutations)
# query 14461 done  (100 permutations computed)
# query 14476 done  (100 permutations computed)
# query 14491 done  (100 permutations computed)
# query 14506 done  (missing 96 permutations)
# query 14521 done  (100 permutations computed)
# query 14536 done  (missing 99 permutations - considering also dataset ranking)
# query 14551 done  (100 permutations computed)
# query 14566 done  (100 permutations computed)
# query 14581 done  (100 permutations computed)
# query 14596 done  (100 permutations computed)
# query 14611 done  (missing 98 permutations)
# query 14626 done  (100 permutations computed)
# query 14641 done  (100 permutations computed)
# query 14656 done  (100 permutations computed)
# query 14671 done  (100 permutations computed)
# query 14686 done  (100 permutations computed)
# query 14701 done  (missing 28 permutations)
# query 14716 done  (100 permutations computed)
# query 14731 done  (100 permutations computed)
# query 14746 done  (missing 88 permutations)
# query 14761 done  (100 permutations computed)
# query 14776 done  (100 permutations computed)
# query 14791 done  (100 permutations computed)
# query 14806 done  (100 permutations computed)
# query 14821 done  (missing 99 permutations)
# query 14836 done  (100 permutations computed)
# query 14851 done  (missing 99 permutations)
# query 14866 done  (100 permutations computed)
# query 14881 done  (100 permutations computed)
# query 14896 done  (all 6 permutations computed)
# query 14911 done  (100 permutations computed)
# query 14926 done  (100 permutations computed)
# query 14941 done  (100 permutations computed)
# query 14956 done  (100 permutations computed)
# query 14971 done  (100 permutations computed)
# query 14986 done  (100 permutations computed)
# query 15001 done  (100 permutations computed)
# query 15016 done  (missing 99 permutations - considering also dataset ranking)
# query 15031 done  (100 permutations computed)
# query 15046 done  (100 permutations computed)
# query 15061 done  (100 permutations computed)
# query 15076 done  (missing 98 permutations)
# query 15091 done  (100 permutations computed)
# query 15106 done  (100 permutations computed)
# query 15121 done  (100 permutations computed)
# query 15136 done  (100 permutations computed)
# query 15151 done  (100 permutations computed)
# query 15166 done  (100 permutations computed)
# query 15181 done  (missing 90 permutations)
# query 15196 done  (100 permutations computed)
# query 15211 done  (100 permutations computed)
# query 15226 done  (100 permutations computed)
# query 15241 done  (100 permutations computed)
# query 15256 done  (100 permutations computed)
# query 15271 done  (100 permutations computed)
# query 15286 done  (100 permutations computed)
# query 15301 done  (100 permutations computed)
# query 15316 done  (100 permutations computed)
# query 15331 done  (100 permutations computed)
# query 15346 done  (100 permutations computed)
# query 15361 done  (100 permutations computed)
# query 15376 done  (100 permutations computed)
# query 15391 done  (100 permutations computed)
# query 15406 done  (100 permutations computed)
# query 15421 done  (100 permutations computed)
# query 15436 done  (missing 99 permutations - considering also dataset ranking)
# query 15451 done  (missing 93 permutations)
# query 15466 done  (100 permutations computed)
# query 15481 done  (100 permutations computed)
# query 15496 done  (100 permutations computed)
# query 15511 done  (100 permutations computed)
# query 15526 done  (100 permutations computed)
# query 15541 done  (100 permutations computed)
# query 15556 done  (100 permutations computed)
# query 15571 done  (100 permutations computed)
# query 15586 done  (100 permutations computed)
# query 15601 done  (100 permutations computed)
# query 15616 done  (100 permutations computed)
# query 15631 done  (100 permutations computed)
# query 15646 done  (100 permutations computed)
# query 15661 done  (100 permutations computed)
# query 15676 done  (100 permutations computed)
# query 15691 done  (100 permutations computed)
# query 15706 done  (100 permutations computed)
# ...
# query 24877 done  (100 permutations computed)
# query 24892 done  (100 permutations computed)
# query 24907 done  (100 permutations computed)
# query 24922 done  (100 permutations computed)
# query 24937 done  (100 permutations computed)
# query 24952 done  (missing 88 permutations)
# query 24967 done  (100 permutations computed)
# query 24982 done  (100 permutations computed)
# query 24997 done  (100 permutations computed)
# query 25012 done  (100 permutations computed)
# query 25027 done  (100 permutations computed)
# query 25042 done  (100 permutations computed)
# query 25057 done  (100 permutations computed)
# query 25072 done  (100 permutations computed)
# query 25087 done  (missing 90 permutations)
# query 25102 done  (100 permutations computed)
# query 25117 done  (100 permutations computed)
# query 25132 done  (100 permutations computed)
# query 25147 done  (100 permutations computed)
# query 25162 done  (missing 30 permutations)
# query 25177 done  (missing 86 permutations)
# query 25192 done  (100 permutations computed)
# query 25207 done  (100 permutations computed)
# query 25222 done  (100 permutations computed)
# query 25237 done  (100 permutations computed)
# query 25252 done  (100 permutations computed)
# query 25267 done  (100 permutations computed)
# query 25282 done  (100 permutations computed)
# query 25297 done  (100 permutations computed)
# query 25312 done  (100 permutations computed)
# query 25327 done  (100 permutations computed)
# query 25342 done  (missing 88 permutations)
# query 25357 done  (missing 98 permutations)
# query 25372 done  (100 permutations computed)
# query 25387 done  (100 permutations computed)
# query 25402 done  (100 permutations computed)
# query 25417 done  (100 permutations computed)
# query 25432 done  (100 permutations computed)
# query 25447 done  (100 permutations computed)
# query 25462 done  (missing 75 permutations)
# query 25477 done  (100 permutations computed)
# query 25492 done  (100 permutations computed)
# query 25507 done  (100 permutations computed)
# query 25522 done  (100 permutations computed)
# query 25537 done  (missing 99 permutations - considering also dataset ranking)
# query 25552 done  (100 permutations computed)
# query 25567 done  (100 permutations computed)
# query 25582 done  (100 permutations computed)
# query 25597 done  (100 permutations computed)
# query 25612 done  (100 permutations computed)
# query 25627 done  (missing 74 permutations)
# query 25642 done  (100 permutations computed)
# query 25657 done  (100 permutations computed)
# query 25672 done  (100 permutations computed)
# query 25687 done  (100 permutations computed)
# query 25702 done  (100 permutations computed)
# query 25717 done  (missing 88 permutations)
# query 25732 done  (missing 81 permutations)
# query 25747 done  (100 permutations computed)
# query 25762 done  (100 permutations computed)
# query 25777 done  (100 permutations computed)
# query 25792 done  (100 permutations computed)
# query 25807 done  (missing 95 permutations)
# query 25822 done  (100 permutations computed)
# query 25837 done  (100 permutations computed)
# query 25852 done  (100 permutations computed)
# query 25867 done  (missing 76 permutations)
# query 25882 done  (missing 99 permutations - considering also dataset ranking)
# query 25897 done  (missing 95 permutations)
# query 25912 done  (missing 96 permutations)
# query 25927 done  (100 permutations computed)
# query 25942 done  (100 permutations computed)
# query 25957 done  (100 permutations computed)
# query 25972 done  (missing 99 permutations - considering also dataset ranking)
# query 25987 done  (100 permutations computed)
# query 26002 done  (100 permutations computed)
# query 26017 done  (100 permutations computed)
# query 26032 done  (100 permutations computed)
# query 26047 done  (missing 99 permutations - considering also dataset ranking)
# query 26062 done  (100 permutations computed)
# query 26077 done  (100 permutations computed)
# query 26092 done  (100 permutations computed)
# query 26107 done  (100 permutations computed)
# query 26122 done  (100 permutations computed)
# query 26137 done  (missing 65 permutations)
# query 26152 done  (100 permutations computed)
# query 26167 done  (100 permutations computed)
# query 26182 done  (100 permutations computed)
# query 26197 done  (100 permutations computed)
# query 26212 done  (missing 94 permutations)
# query 26227 done  (100 permutations computed)
# query 26242 done  (missing 78 permutations)
# query 26257 done  (100 permutations computed)
# query 26272 done  (100 permutations computed)
# query 26287 done  (100 permutations computed)
# query 26302 done  (100 permutations computed)
# query 26317 done  (100 permutations computed)
# query 26332 done  (100 permutations computed)
# query 26347 done  (100 permutations computed)
# query 26362 done  (100 permutations computed)
# query 26377 done  (100 permutations computed)
# query 26392 done  (100 permutations computed)
# query 26407 done  (100 permutations computed)
# query 26422 done  (100 permutations computed)
# query 26437 done  (100 permutations computed)
# query 26452 done  (100 permutations computed)
# query 26467 done  (100 permutations computed)
# query 26482 done  (100 permutations computed)
# query 26497 done  (100 permutations computed)
# query 26512 done  (100 permutations computed)
# query 26527 done  (100 permutations computed)
# query 26542 done  (100 permutations computed)
# query 26557 done  (100 permutations computed)
# query 26572 done  (100 permutations computed)
# query 26587 done  (100 permutations computed)
# query 26602 done  (100 permutations computed)
# query 26617 done  (100 permutations computed)
# query 26632 done  (missing 95 permutations)
# query 26647 done  (100 permutations computed)
# query 26662 done  (100 permutations computed)
# query 26677 done  (100 permutations computed)
# query 26692 done  (100 permutations computed)
# query 26707 done  (100 permutations computed)
# query 26722 done  (100 permutations computed)
# query 26737 done  (100 permutations computed)
# query 26752 done  (100 permutations computed)
# query 26767 done  (100 permutations computed)
# query 26782 done  (100 permutations computed)
# query 26797 done  (100 permutations computed)
# query 26812 done  (100 permutations computed)
# query 26827 done  (100 permutations computed)
# query 26842 done  (100 permutations computed)
# query 26857 done  (100 permutations computed)
# query 26872 done  (100 permutations computed)
# query 26887 done  (100 permutations computed)
# query 26902 done  (100 permutations computed)
# query 26917 done  (missing 90 permutations)
# query 26932 done  (100 permutations computed)
# query 26947 done  (100 permutations computed)
# query 26962 done  (100 permutations computed)
# query 26977 done  (100 permutations computed)
# query 26992 done  (100 permutations computed)
# query 27007 done  (100 permutations computed)
# query 27022 done  (100 permutations computed)
# query 27037 done  (100 permutations computed)
# query 27052 done  (missing 78 permutations)
# query 27067 done  (100 permutations computed)
# query 27082 done  (100 permutations computed)
# query 27097 done  (missing 92 permutations)
# query 27112 done  (100 permutations computed)
# query 27127 done  (100 permutations computed)
# query 27142 done  (100 permutations computed)
# query 27157 done  (100 permutations computed)
# query 27172 done  (100 permutations computed)
# query 27187 done  (100 permutations computed)
# query 27202 done  (missing 99 permutations - considering also dataset ranking)
# query 27217 done  (missing 65 permutations)
# query 27232 done  (100 permutations computed)
# query 27247 done  (100 permutations computed)
# query 27262 done  (100 permutations computed)
# query 27277 done  (100 permutations computed)
# query 27292 done  (100 permutations computed)
# query 27307 done  (100 permutations computed)
# query 27322 done  (100 permutations computed)
# query 27337 done  (100 permutations computed)
# query 27352 done  (100 permutations computed)
# query 27367 done  (missing 80 permutations)
# query 27382 done  (100 permutations computed)
# query 27397 done  (100 permutations computed)
# query 27412 done  (100 permutations computed)
# query 27427 done  (100 permutations computed)
# query 27442 done  (100 permutations computed)
# query 27457 done  (100 permutations computed)
# query 27472 done  (100 permutations computed)
# query 27487 done  (missing 86 permutations)
# query 27502 done  (100 permutations computed)
# query 27517 done  (100 permutations computed)
# query 27532 done  (100 permutations computed)
# query 27547 done  (100 permutations computed)
# query 27562 done  (100 permutations computed)
# query 27577 done  (100 permutations computed)
# query 27592 done  (100 permutations computed)
# query 27607 done  (100 permutations computed)
# query 27622 done  (100 permutations computed)
# query 27637 done  (100 permutations computed)
# query 27652 done  (100 permutations computed)
# query 27667 done  (100 permutations computed)
# query 27682 done  (missing 99 permutations)
# query 27697 done  (100 permutations computed)
# query 27712 done  (100 permutations computed)
# query 27727 done  (100 permutations computed)
# query 27742 done  (100 permutations computed)
# query 27757 done  (100 permutations computed)
# query 27772 done  (100 permutations computed)
# query 27787 done  (missing 64 permutations)
# query 27802 done  (100 permutations computed)
# query 27817 done  (100 permutations computed)
# query 27832 done  (100 permutations computed)
# query 27847 done  (missing 97 permutations)
# query 27862 done  (100 permutations computed)
# query 27877 done  (missing 96 permutations)
# query 27892 done  (100 permutations computed)
# query 27907 done  (100 permutations computed)
# query 27922 done  (100 permutations computed)
# query 27937 done  (100 permutations computed)
# query 27952 done  (100 permutations computed)
# query 27967 done  (100 permutations computed)
# query 27982 done  (100 permutations computed)
# query 27997 done  (100 permutations computed)
# query 28012 done  (missing 61 permutations)
# query 28027 done  (100 permutations computed)
# query 28042 done  (100 permutations computed)
# query 28057 done  (100 permutations computed)
# query 28072 done  (100 permutations computed)
# query 28087 done  (100 permutations computed)
# query 28102 done  (missing 85 permutations)
# query 28117 done  (100 permutations computed)
# query 28132 done  (100 permutations computed)
# query 28147 done  (missing 45 permutations)
# query 28162 done  (100 permutations computed)
# query 28177 done  (100 permutations computed)
# query 28192 done  (missing 99 permutations - considering also dataset ranking)
# query 28207 done  (100 permutations computed)
# query 28222 done  (missing 94 permutations)
# query 28237 done  (100 permutations computed)
# query 28252 done  (100 permutations computed)
# query 28267 done  (missing 99 permutations)
# query 28282 done  (100 permutations computed)
# query 28297 done  (100 permutations computed)
# query 28312 done  (100 permutations computed)
# query 28327 done  (100 permutations computed)
# query 28342 done  (100 permutations computed)
# query 28357 done  (100 permutations computed)
# query 28372 done  (missing 80 permutations)
# query 28387 done  (100 permutations computed)
# query 28402 done  (missing 84 permutations)
# query 28417 done  (missing 96 permutations)
# query 28432 done  (100 permutations computed)
# query 28447 done  (100 permutations computed)
# query 28462 done  (100 permutations computed)
# query 28477 done  (100 permutations computed)
# query 28492 done  (100 permutations computed)
# query 28507 done  (100 permutations computed)
# query 28522 done  (100 permutations computed)
# query 28537 done  (100 permutations computed)
# query 28552 done  (100 permutations computed)
# query 28567 done  (100 permutations computed)
# query 28582 done  (100 permutations computed)
# query 28597 done  (100 permutations computed)
# query 28612 done  (100 permutations computed)
# query 28627 done  (100 permutations computed)
# query 28642 done  (100 permutations computed)
# query 28657 done  (missing 90 permutations)
# query 28672 done  (100 permutations computed)
# query 28687 done  (100 permutations computed)
# query 28702 done  (100 permutations computed)
# query 28717 done  (missing 84 permutations)
# query 28732 done  (100 permutations computed)
# query 28747 done  (100 permutations computed)
# query 28762 done  (100 permutations computed)
# query 28777 done  (100 permutations computed)
# query 28792 done  (100 permutations computed)
# query 28807 done  (100 permutations computed)
# query 28822 done  (100 permutations computed)
# query 28837 done  (100 permutations computed)
# query 28852 done  (100 permutations computed)
# query 28867 done  (100 permutations computed)
# query 28882 done  (100 permutations computed)
# query 28897 done  (100 permutations computed)
# query 28912 done  (100 permutations computed)
# query 28927 done  (100 permutations computed)
# query 28942 done  (100 permutations computed)
# query 28957 done  (100 permutations computed)
# query 28972 done  (all 2 permutations computed)
# query 28987 done  (missing 99 permutations - considering also dataset ranking)
# query 29002 done  (missing 28 permutations)
# query 29017 done  (100 permutations computed)
# query 29032 done  (100 permutations computed)
# query 29047 done  (100 permutations computed)
# query 29062 done  (100 permutations computed)
# query 29077 done  (100 permutations computed)
# query 29092 done  (100 permutations computed)
# query 29107 done  (100 permutations computed)
# query 29122 done  (100 permutations computed)
# query 29137 done  (100 permutations computed)
# query 29152 done  (100 permutations computed)
# query 29167 done  (100 permutations computed)
# query 29182 done  (100 permutations computed)
# query 29197 done  (100 permutations computed)
# query 29212 done  (100 permutations computed)
# query 29227 done  (100 permutations computed)
# query 29242 done  (100 permutations computed)
# query 29257 done  (100 permutations computed)
# query 29272 done  (all 2 permutations computed)
# query 29287 done  (100 permutations computed)
# query 29302 done  (missing 87 permutations)
# query 29317 done  (100 permutations computed)
# query 29332 done  (100 permutations computed)
# query 29347 done  (100 permutations computed)
# query 29362 done  (100 permutations computed)
# query 29377 done  (missing 99 permutations)
# query 29392 done  (100 permutations computed)
# query 29407 done  (100 permutations computed)
# query 29422 done  (100 permutations computed)
# query 29437 done  (100 permutations computed)
# query 29452 done  (100 permutations computed)
# query 29467 done  (100 permutations computed)
# query 29482 done  (100 permutations computed)
# query 29497 done  (100 permutations computed)
# query 29512 done  (100 permutations computed)
# query 29527 done  (100 permutations computed)
# query 29542 done  (100 permutations computed)
# query 29557 done  (100 permutations computed)
# query 29572 done  (100 permutations computed)
# query 29587 done  (missing 96 permutations)
# query 29602 done  (100 permutations computed)
# query 29617 done  (100 permutations computed)
# query 29632 done  (100 permutations computed)
# query 29647 done  (100 permutations computed)
# query 29662 done  (100 permutations computed)
# query 29677 done  (100 permutations computed)
# query 29692 done  (missing 18 permutations)
# query 29707 done  (missing 84 permutations)
# query 29722 done  (100 permutations computed)
# query 29737 done  (100 permutations computed)
# query 29752 done  (100 permutations computed)
# query 29767 done  (100 permutations computed)
# query 29782 done  (100 permutations computed)
# query 29797 done  (100 permutations computed)
# query 29812 done  (100 permutations computed)
# query 29827 done  (100 permutations computed)
# query 29842 done  (missing 60 permutations)
# query 29857 done  (100 permutations computed)
# query 29872 done  (100 permutations computed)
# query 29887 done  (100 permutations computed)
# query 29902 done  (100 permutations computed)
# query 29917 done  (100 permutations computed)
# query 29932 done  (100 permutations computed)
# query 29947 done  (100 permutations computed)
# query 29962 done  (100 permutations computed)
# query 29977 done  (100 permutations computed)
# query 29992 done  (missing 99 permutations)
# sample set creation took 1753.5625 s
# done

# %%
def check(q, k):
    indexes = set(range(0, len(q.perms)))
    indexes.remove(k)
    result = []
    for i in range(len(q.perms[k])):
        tmp = set(indexes)
        for j in tmp:
            if q.perms[k][i] != q.perms[j][i]:
                indexes.remove(j)
    for w in indexes:
        if w < k:
            result.append((w, k))
        else: 
            result.append((k,w))
    return result

same = dict()
for q in queries.values():
    for i in range(len(q.perms)):
        r = check(q, i)
        if len(r) != 0:
            if not q.qid in same.keys():
                same[q.qid] = set()
            for t in r:
                same[q.qid].add(t)
            
print(str(len(same.keys())) + "/" + str(len(queries.keys())) + " queries have duplicate permutations")
for q, s in same.items():
    print("query " + str(q) + " has repeated permutations: " + str(s))

# %%
#
# Define evaluation metric and objective function
#

# current predictions, dataset => name, score, true iff higher means better
def mse_eval(preds, train_data):
    labels = train_data.get_label()
    avg_mse = 0.5 * np.mean( (labels-preds)**2 )
    return METRIC_NAME, avg_mse, False

# current predictions, dataset => first order derivative, second order derivative
def mse_grads(preds, train_data): 
    #labels = train_data.get_label()
    #lam = .9
    #lam * something * (1-lam)*cross_entropy(i, preds)
        
    global queries
    global doc_to_query
    
    query_to_entropy = {}
    for q in queries.values():
        query_to_entropy[q.qid] = cross_entropy(q.perms, q.probs, preds)
    
    gain = np.zeros_like(preds)
    for i in range(len(gain)):
        gain[i] = query_to_entropy[doc_to_query[i]]
    #grad = preds - labels 
    hess = np.ones_like(gain) 
    return gain, hess

# %%
#
# Train the model
#

params = {
#    'objective':'lambdarank', # what to optimize during training
#    'max_position': 10,      # threshold used in optimizing lamdarank (NDCG)
    'learning_rate': 0.1,
    'num_leaves': 16,
    'min_data_in_leaf': 5,
    'metric': ['None'], #['ndcg'],       # what to use/print for evaluation
#    'ndcg_eval_at': 10
# try printing ndcg and testing
}    

print("training lightgbm...")
start = time.process_time()
lgbm_info = {}
lgbm_model = lightgbm.train(params, train_lgb, num_boost_round=100,
                            feval = mse_eval,
                            fobj  = mse_grads,
                            valid_sets   = [train_lgb, valid_lgb, test_lgb], 
                            valid_names  = ["train", "valid", "test"],
                            evals_result = lgbm_info,
                            verbose_eval = 1)
print("training took " + str(time.process_time() - start) + " s")
print("done")

# lgbm_info
# Out:
# training lightgbm...

# %%
#
# Plot the results
#

plt.figure(figsize=(9,6), tight_layout=True)

plt.plot(lgbm_info['train'][METRIC_NAME], label='training')
plt.plot(lgbm_info['valid'][METRIC_NAME], label='validation')
plt.plot(lgbm_info['test'][METRIC_NAME], label='test')

plt.grid()
plt.legend()
plt.xlabel("# Trees")
plt.ylabel(METRIC_NAME)
plt.title("Model Error")
